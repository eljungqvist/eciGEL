# %% [markdown]
# #  Script to update iGEL604 and prepare it for ec model generation using GECKO
#
# # To do:
#
#     # model = addReaction(model, 'FA_composition', 'reactionName', 'Cell membrane fatty acid composition pseudoreaction', 'reactionFormula', '2.78 C00249 + 1.02 C01530 + 0.06 C06424 -> 1 Membrane_FAs');
#     # model = addReaction(model, 'CellMembrane', 'reactionName', 'Cell membrane pseudoreaction', 'reactionFormula', '1.93 C00093 + 1 Membrane_FAs -> 1.272 Cellmembrane');

# %%
import cobra
import os
import pandas as pd
import math

# %%
model = cobra.io.load_json_model('../../Models/iGEL604.json')  # Reads iGEL604

# %%
model  # Starting stats of iGEL604
# Out:
# <Model model at 0x10b6a7a30>

# %%
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass = 0.9967806797490679</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00014[c]</td>
#       <td>EX_Ammonia</td>
#       <td>9.749</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00120_e[e]</td>
#       <td>EX_Biotin</td>
#       <td>0.01116</td>
#       <td>10</td>
#       <td>0.16%</td>
#     </tr>
#     <tr>
#       <td>C14818_e[e]</td>
#       <td>EX_Fe</td>
#       <td>0.004466</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00504_e[e]</td>
#       <td>EX_Folate</td>
#       <td>0.00614</td>
#       <td>19</td>
#       <td>0.17%</td>
#     </tr>
#     <tr>
#       <td>C00080[c]</td>
#       <td>EX_H</td>
#       <td>13.57</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00253_e[e]</td>
#       <td>EX_Nicotinicacid</td>
#       <td>0.02718</td>
#       <td>6</td>
#       <td>0.24%</td>
#     </tr>
#     <tr>
#       <td>C00009_e[e]</td>
#       <td>EX_Orthophosphate</td>
#       <td>1.138</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00007[c]</td>
#       <td>EX_Oxygen</td>
#       <td>32.66</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00059[c]</td>
#       <td>EX_Sulfate</td>
#       <td>0.1521</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00378_e[e]</td>
#       <td>EX_Thiamine</td>
#       <td>0.0006698</td>
#       <td>12</td>
#       <td>0.01%</td>
#     </tr>
#     <tr>
#       <td>C00181_e[e]</td>
#       <td>EX_Xylose</td>
#       <td>13.61</td>
#       <td>5</td>
#       <td>99.42%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Biomass[c]</td>
#       <td>EX_Biomass</td>
#       <td>-0.9968</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00011[c]</td>
#       <td>EX_CO2</td>
#       <td>-32.33</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>C00001[c]</td>
#       <td>EX_H2O</td>
#       <td>-57.37</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
#  Many reactions, e.g. exchange reactions, needs naming
for reaction in model.exchanges:
    print("%s  %s" %(reaction.id, reaction.name))
# Out:
# EX_Galactose
# EX_Mannose
# EX_Xylose
# EX_Glucose
# EX_Orthophosphate
# EX_Molybdate
# EX_VitB12
# EX_PyridoxinHydrochloride
# EX_Thiamine
# EX_Nicotinicacid
# EX_paminobenzoate
# EX_Biotin
# EX_Folate
# EX_Fe
# EX_C00116[e]  EX_C00116[e]
# EX_C00089[e]  EX_C00089[e]
# EX_C00185[e]  EX_C00185[e]
# EX_C00259[e]  EX_C00259[e]
# EX_C00249[e]  EX_C00249[e]
# EX_C00246[e]  EX_C00246[e]

# %%
# Adds some missing reaction names. Needs updating "L" and "D" for some of the sugars. 
# More names can be added to csv file later.

reactionNamesToUpdate = pd.read_csv('Reaction_names.csv')

rxnIDs = reactionNamesToUpdate['Reaction'].tolist()  # List of reaction IDs in iGEL604 that lacks names
rxnNames = reactionNamesToUpdate['Reaction name'].tolist()  # List of reaction names to add to model

for i, rxnID in enumerate(rxnIDs):  # Loops over rxnIDs and updates model using the corresponding rxn names
    model.reactions.get_by_id(rxnID).name = rxnNames[i]
    
for reaction in model.exchanges:
    print("%s  %s %s" %(reaction.id, reaction.name, reaction.bounds))
# Out:
# EX_Galactose  Galactose exchange (0.0, 0.0)
# EX_Mannose  Mannose exchange (0.0, 0.0)
# EX_Xylose  Xylose exchange (-13.61, 0.0)
# EX_Glucose  D-Glucose exchange (0.0, 0.0)
# EX_Orthophosphate  Orthophosphate exchange (-1000.0, 1000.0)
# EX_Molybdate  Molybdate exchange (-1000.0, 0.0)
# EX_VitB12  Vitamin B12 exchange (-1000.0, 0.0)
# EX_PyridoxinHydrochloride  Pyridoxin exchange (-1000.0, 0.0)
# EX_Thiamine  Thiamine exchange (-1000.0, 0.0)
# EX_Nicotinicacid  Nicotinic acid exchange (-1000.0, 0.0)
# EX_paminobenzoate  p-Aminobenzoic acid exchange (-1000.0, 0.0)
# EX_Biotin  Biotin exchange (-1000.0, 0.0)
# EX_Folate  Folate exchange (-1000.0, 0.0)
# EX_Fe  Iron exchange (-1000.0, 0.0)
# EX_C00116[e]  Glycerol exchange (0.0, 0.0)
# EX_C00089[e]  Sucrose exchange (0.0, 0.0)
# EX_C00185[e]  Cellobiose exchange (0.0, 0.0)
# EX_C00259[e]  L-Arabinose exchange (0.0, 0.0)
# EX_C00249[e]  Palmitic acid exchange (0.0, 0.0)
# EX_C00246[e]  Butanoic acid exchange (0.0, 0.0)

# %%
# Update reaction bounds for uptake reactions to avoid losing them during GECKO preprocessing
model.reactions.get_by_id('EX_Galactose').bounds = (-1000, 0.0)
model.reactions.get_by_id('EX_Mannose').bounds = (-1000, 0.0)
model.reactions.get_by_id('EX_Glucose').bounds = (-1000, 0.0)
model.reactions.get_by_id('EX_C00116[e]').bounds = (-1000, 0.0)
model.reactions.get_by_id('EX_C00089[e]').bounds = (-1000, 0.0)
model.reactions.get_by_id('EX_C00185[e]').bounds = (-1000, 0.0)
model.reactions.get_by_id('EX_C00259[e]').bounds = (-1000, 0.0)
model.reactions.get_by_id('EX_C00249[e]').bounds = (-1000, 0.0)
model.reactions.get_by_id('EX_C00246[e]').bounds = (-1000, 0.0)

for reaction in model.exchanges:
    print("%s  %s %s" %(reaction.id, reaction.name, reaction.bounds))
# Out:
# EX_Galactose  Galactose exchange (-1000, 0.0)
# EX_Mannose  Mannose exchange (-1000, 0.0)
# EX_Xylose  Xylose exchange (-13.61, 0.0)
# EX_Glucose  D-Glucose exchange (-1000, 0.0)
# EX_Orthophosphate  Orthophosphate exchange (-1000.0, 1000.0)
# EX_Molybdate  Molybdate exchange (-1000.0, 0.0)
# EX_VitB12  Vitamin B12 exchange (-1000.0, 0.0)
# EX_PyridoxinHydrochloride  Pyridoxin exchange (-1000.0, 0.0)
# EX_Thiamine  Thiamine exchange (-1000.0, 0.0)
# EX_Nicotinicacid  Nicotinic acid exchange (-1000.0, 0.0)
# EX_paminobenzoate  p-Aminobenzoic acid exchange (-1000.0, 0.0)
# EX_Biotin  Biotin exchange (-1000.0, 0.0)
# EX_Folate  Folate exchange (-1000.0, 0.0)
# EX_Fe  Iron exchange (-1000.0, 0.0)
# EX_C00116[e]  Glycerol exchange (-1000, 0.0)
# EX_C00089[e]  Sucrose exchange (-1000, 0.0)
# EX_C00185[e]  Cellobiose exchange (-1000, 0.0)
# EX_C00259[e]  L-Arabinose exchange (-1000, 0.0)
# EX_C00249[e]  Palmitic acid exchange (-1000, 0.0)
# EX_C00246[e]  Butanoic acid exchange (-1000, 0.0)

# %%
# Remove some reactions that were added during iGEL604 testing
rxnIDs_to_remove = ['EX_3HB', '3HB_thioesterase','EX_Ethanol']

model.remove_reactions(rxnIDs_to_remove, remove_orphans=True)

# %%
# Model now strongly oversetimates growth since all exchanges are open. Also makes tons of lactate. 
#No longer valid for modelling, but will be fixed during the Gecko workflow.
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 Biomass = 12.246124388311925</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>C00014[c]</td>
#       <td>EX_Ammonia</td>
#       <td>119.8</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00120_e[e]</td>
#       <td>EX_Biotin</td>
#       <td>0.1372</td>
#       <td>10</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <td>C00116[e]</td>
#       <td>EX_C00116[e]</td>
#       <td>60.77</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C14818_e[e]</td>
#       <td>EX_Fe</td>
#       <td>0.05486</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00504_e[e]</td>
#       <td>EX_Folate</td>
#       <td>0.07544</td>
#       <td>19</td>
#       <td>0.05%</td>
#     </tr>
#     <tr>
#       <td>C00031_e[e]</td>
#       <td>EX_Glucose</td>
#       <td>503.8</td>
#       <td>6</td>
#       <td>99.84%</td>
#     </tr>
#     <tr>
#       <td>C00253_e[e]</td>
#       <td>EX_Nicotinicacid</td>
#       <td>0.334</td>
#       <td>6</td>
#       <td>0.07%</td>
#     </tr>
#     <tr>
#       <td>C00009_e[e]</td>
#       <td>EX_Orthophosphate</td>
#       <td>13.99</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00007[c]</td>
#       <td>EX_Oxygen</td>
#       <td>34.41</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00059[c]</td>
#       <td>EX_Sulfate</td>
#       <td>1.868</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00378_e[e]</td>
#       <td>EX_Thiamine</td>
#       <td>0.008229</td>
#       <td>12</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Biomass[c]</td>
#       <td>EX_Biomass</td>
#       <td>-12.25</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00080[c]</td>
#       <td>EX_H</td>
#       <td>-755.3</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00001[c]</td>
#       <td>EX_H2O</td>
#       <td>-368.4</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>C00186[c]</td>
#       <td>EX_Lactate</td>
#       <td>-922</td>
#       <td>3</td>
#       <td>100.00%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Fix substrate SMILES

# %%
import requests
from bioservices import *

class metab_data_container:
    # Class that holds data for a metabolite from a cobry.core.model.metabolites
    

    
    def __init__(self, metabolite):
        self.id_in_model = metabolite.id
        
        self.kegg_id = self.format_id()
        
        self.metname = self.retreive_name()
        
        self.smiles = self.retrieve_smiles()
    
    
    
    def format_id(self):
        # Formats metabolite ID from iGEL604 to kegg compound id format
        kegg_id = self.id_in_model
        if '_e' in kegg_id:
            kegg_id = kegg_id.replace('_e', '')
        
        if  kegg_id[0:2] in ['C0','C1','C2']:
            kegg_id = kegg_id.rstrip('[c]').rstrip('[e]')  # Removes compartment identifiers
        return kegg_id
    
    def retreive_name(self):
        metabolite = self.kegg_id
        kegg_con = KEGG()

        try:
            kegg_con = KEGG()
            metname = kegg_con.parse(kegg_con.get(metabolite))['NAME']
        except: 
            metname = None
            
        return metname
        
    
    def retrieve_smiles(self):
        smiles = ''
        if self.metname is not None:
            for n in self.metname:  # Checks all names for smiles
                try:
                    url = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/%s/property/CanonicalSMILES/TXT' % n
                    req = requests.get(url)
                    if req.status_code == 200:
                        smiles = req.content.splitlines()[0].decode()
                        break  # If smiles found, set smiles for metabolite and end here
                except :
                        pass
        return smiles  # Return smiles
    
    def get_id_and_smiles(self):
        return [self.id_in_model, self.smiles]

# %%
# Testing that the class works. Seems to work overall
testmetab = metab_data_container(model.metabolites[13])
print(testmetab.id_in_model)
print(testmetab.kegg_id)
print(testmetab.metname)
print(testmetab.smiles)
print(testmetab.get_id_and_smiles())
# Out:
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/UDP;/property/CanonicalSMILES/TXT
# https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/Uridine 5'-diphosphate/property/CanonicalSMILES/TXT
# C00015[c]
# C00015
# ['UDP;', "Uridine 5'-diphosphate"]
# C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)O)O)O
# ['C00015[c]', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)O)O)O']

# %%
# Test looping through some metabolites

metabolite_data_containers = []
metabolite_id_list = []
smiles_list = []

for metabolite in model.metabolites[0:10]:
    metab_data = metab_data_container(metabolite)
    metabolite_data_containers.append(metab_data)
    
for item in metabolite_data_containers:
    data = item.get_id_and_smiles()
    metabolite_id_list.append(data[0])
    smiles_list.append(data[1])
    
print(metabolite_id_list)
print(smiles_list)
# Out:
# ['C00001[c]', 'C00002[c]', 'C00003[c]', 'C00004[c]', 'C00005[c]', 'C00006[c]', 'C00007[c]', 'C00008[c]', 'C00009[c]', 'C00010[c]']
# ['O', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)N', 'C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)([O-])OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O)C(=O)N', 'C1C=CN(C=C1C(=O)N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O', 'C1C=CN(C=C1C(=O)N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)OP(=O)(O)O)O)O)O', 'C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)OP(=O)(O)O)O)O)O)C(=O)N', 'O=O', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O)N', 'OP(=O)(O)O', 'CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCS)O']

# %%
# Loop trhough all metabolites
metabolite_data_containers = []
metabolite_id_list = []
smiles_list = []

for metabolite in model.metabolites[0:10]:
    metab_data = metab_data_container(metabolite)
    metabolite_data_containers.append(metab_data)
    
for item in metabolite_data_containers:
    data = item.get_id_and_smiles()
    metabolite_id_list.append(data[0])
    smiles_list.append(data[1])
    
print(metabolite_id_list)
print(smiles_list)

# %%
print(model.metabolites[1204:1210])
print(len(metabolite_data_containers))  # Crashed after 1205
# Out:
# [<Metabolite C20781[c] at 0x125d78eb0>, <Metabolite C20797[c] at 0x125d78ee0>, <Metabolite C20798[c] at 0x125d78f10>, <Metabolite C20830[c] at 0x125d78f40>, <Metabolite C20831[c] at 0x125d78f70>, <Metabolite C20838[c] at 0x125d78fa0>]
# 1205

# %%
templist = []
for item in metabolite_data_containers:
    templist.append(item.id_in_model)

for item in templist:
    print(item)
# Out:
# C00001[c]
# C00002[c]
# C00003[c]
# C00004[c]
# C00005[c]
# C00006[c]
# C00007[c]
# C00008[c]
# C00009[c]
# C00010[c]
# C00011[c]
# C00013[c]
# C00014[c]
# C00015[c]
# C00016[c]
# C00018[c]
# C00019[c]
# C00020[c]
# C00021[c]
# C00022[c]
# C00024[c]
# C00025[c]
# C00026[c]
# C00027[c]
# C00029[c]
# C00031[c]
# C00032[c]
# C00033[c]
# C00035[c]
# C00036[c]
# C00037[c]
# C00041[c]
# C00042[c]
# C00043[c]
# C00044[c]
# C00047[c]
# C00048[c]
# C00049[c]
# C00051[c]
# C00052[c]
# C00053[c]
# C00054[c]
# C00055[c]
# C00058[c]
# C00059[c]
# C00061[c]
# C00062[c]
# C00063[c]
# C00064[c]
# C00065[c]
# C00067[c]
# C00068[c]
# C00072[c]
# C00073[c]
# C00074[c]
# C00075[c]
# C00077[c]
# C00078[c]
# C00079[c]
# C00080[c]
# C00081[c]
# C00082[c]
# C00083[c]
# C00084[c]
# C00085[c]
# C00086[c]
# C00088[c]
# C00089[c]
# C00091[c]
# C00092[c]
# C00093[c]
# C00094[c]
# C00095[c]
# C00096[c]
# C00097[c]
# C00099[c]
# C00100[c]
# C00101[c]
# C00103[c]
# C00104[c]
# C00105[c]
# C00106[c]
# C00108[c]
# C00109[c]
# C00111[c]
# C00112[c]
# C00114[c]
# C00116[c]
# C00117[c]
# C00118[c]
# C00119[c]
# C00120[c]
# C00121[c]
# C00122[c]
# C00123[c]
# C00124[c]
# C00127[c]
# C00129[c]
# C00130[c]
# C00131[c]
# C00132[c]
# C00133[c]
# C00134[c]
# C00135[c]
# C00136[c]
# C00137[c]
# C00138[c]
# C00139[c]
# C00140[c]
# C00141[c]
# C00143[c]
# C00144[c]
# C00147[c]
# C00148[c]
# C00149[c]
# C00152[c]
# C00153[c]
# C00154[c]
# C00155[c]
# C00156[c]
# C00158[c]
# C00159[c]
# C00160[c]
# C00163[c]
# C00164[c]
# C00166[c]
# C00167[c]
# C00168[c]
# C00169[c]
# C00170[c]
# C00178[c]
# C00179[c]
# C00180[c]
# C00181[c]
# C00183[c]
# C00184[c]
# C00185[c]
# C00186[c]
# C00188[c]
# C00189[c]
# C00190[c]
# C00191[c]
# C00194[c]
# C00196[c]
# C00197[c]
# C00198[c]
# C00199[c]
# C00203[c]
# C00204[c]
# C00206[c]
# C00207[c]
# C00208[c]
# C00209[c]
# C00212[c]
# C00213[c]
# C00214[c]
# C00217[c]
# C00221[c]
# C00222[c]
# C00223[c]
# C00224[c]
# C00227[c]
# C00229[c]
# C00231[c]
# C00232[c]
# C00233[c]
# C00234[c]
# C00235[c]
# C00236[c]
# C00237[c]
# C00239[c]
# C00242[c]
# C00244[c]
# C00245[c]
# C00246[c]
# C00248[c]
# C00249[c]
# C00250[c]
# C00251[c]
# C00252[c]
# C00253[c]
# C00254[c]
# C00255[c]
# C00256[c]
# C00257[c]
# C00258[c]
# C00261[c]
# C00262[c]
# C00263[c]
# C00266[c]
# C00267[c]
# C00272[c]
# C00275[c]
# C00279[c]
# C00280[c]
# C00282[c]
# C00283[c]
# C00286[c]
# C00288[c]
# C00294[c]
# C00295[c]
# C00299[c]
# C00301[c]
# C00302[c]
# C00310[c]
# C00311[c]
# C00312[c]
# C00313[c]
# C00314[c]
# C00315[c]
# C00318[c]
# C00320[c]
# C00322[c]
# C00323[c]
# C00327[c]
# C00330[c]
# C00331[c]
# C00332[c]
# C00334[c]
# C00337[c]
# C00341[c]
# C00342[c]
# C00343[c]
# C00345[c]
# C00349[c]
# C00352[c]
# C00353[c]
# C00354[c]
# C00356[c]
# C00357[c]
# C00360[c]
# C00361[c]
# C00362[c]
# C00363[c]
# C00364[c]
# C00365[c]
# C00366[c]
# C00376[c]
# C00378[c]
# C00380[c]
# C00385[c]
# C00387[c]
# C00390[c]
# C00399[c]
# C00402[c]
# C00406[c]
# C00407[c]
# C00409[c]
# C00411[c]
# C00414[c]
# C00415[c]
# C00417[c]
# C00423[c]
# C00424[c]
# C00430[c]
# C00431[c]
# C00433[c]
# C00436[c]
# C00437[c]
# C00438[c]
# C00440[c]
# C00441[c]
# C00445[c]
# C00446[c]
# C00447[c]
# C00448[c]
# C00455[c]
# C00458[c]
# C00459[c]
# C00460[c]
# C00463[c]
# C00468[c]
# C00469[c]
# C00473[c]
# C00475[c]
# C00479[c]
# C00482[c]
# C00486[c]
# C00489[c]
# C00490[c]
# C00491[c]
# C00492[c]
# C00493[c]
# C00497[c]
# C00498[c]
# C00499[c]
# C00500[c]
# C00502[c]
# C00503[c]
# C00504[c]
# C00506[c]
# C00507[c]
# C00511[c]
# C00512[c]
# C00522[c]
# C00526[c]
# C00527[c]
# C00531[c]
# C00533[c]
# C00535[c]
# C00536[c]
# C00540[c]
# C00542[c]
# C00546[c]
# C00552[c]
# C00555[c]
# C00559[c]
# C00561[c]
# C00568[c]
# C00576[c]
# C00577[c]
# C00579[c]
# C00580[c]
# C00583[c]
# C00587[c]
# C00593[c]
# C00601[c]
# C00603[c]
# C00606[c]
# C00617[c]
# C00618[c]
# C00620[c]
# C00623[c]
# C00624[c]
# C00631[c]
# C00633[c]
# C00636[c]
# C00637[c]
# C00642[c]
# C00645[c]
# C00655[c]
# C00666[c]
# C00670[c]
# C00671[c]
# C00672[c]
# C00673[c]
# C00674[c]
# C00679[c]
# C00680[c]
# C00682[c]
# C00683[c]
# C00688[c]
# C00689[c]
# C00691[c]
# C00692[c]
# C00700[c]
# C00705[c]
# C00719[c]
# C00729[c]
# C00740[c]
# C00741[c]
# C00748[c]
# C00750[c]
# C00755[c]
# C00783[c]
# C00785[c]
# C00789[c]
# C00795[c]
# C00800[c]
# C00802[c]
# C00804[c]
# C00810[c]
# C00811[c]
# C00818[c]
# C00819[c]
# C00826[c]
# C00828[c]
# C00831[c]
# C00842[c]
# C00844[c]
# C00845[c]
# C00846[c]
# C00853[c]
# C00854[c]
# C00857[c]
# C00860[c]
# C00864[c]
# C00870[c]
# C00876[c]
# C00877[c]
# C00881[c]
# C00882[c]
# C00885[c]
# C00894[c]
# C00898[c]
# C00900[c]
# C00921[c]
# C00931[c]
# C00935[c]
# C00937[c]
# C00940[c]
# C00944[c]
# C00951[c]
# C00954[c]
# C00956[c]
# C00957[c]
# C00966[c]
# C00969[c]
# C00973[c]
# C00976[c]
# C00979[c]
# C00984[c]
# C00989[c]
# C00990[c]
# C00993[c]
# C01005[c]
# C01007[c]
# C01010[c]
# C01020[c]
# C01024[c]
# C01035[c]
# C01037[c]
# C01050[c]
# C01051[c]
# C01063[c]
# C01068[c]
# C01077[c]
# C01079[c]
# C01080[c]
# C01081[c]
# C01083[c]
# C01092[c]
# C01094[c]
# C01097[c]
# C01100[c]
# C01102[c]
# C01103[c]
# C01113[c]
# C01118[c]
# C01127[c]
# C01134[c]
# C01137[c]
# C01144[c]
# C01146[c]
# C01149[c]
# C01157[c]
# C01161[c]
# C01163[c]
# C01165[c]
# C01168[c]
# C01170[c]
# C01177[c]
# C01179[c]
# C01180[c]
# C01181[c]
# C01185[c]
# C01197[c]
# C01205[c]
# C01209[c]
# C01212[c]
# C01213[c]
# C01216[c]
# C01217[c]
# C01218[c]
# C01222[c]
# C01227[c]
# C01228[c]
# C01230[c]
# C01233[c]
# C01236[c]
# C01250[c]
# C01251[c]
# C01267[c]
# C01268[c]
# C01269[c]
# C01278[c]
# C01279[c]
# C01286[c]
# C01289[c]
# C01291[c]
# C01300[c]
# C01302[c]
# C01304[c]
# C01327[c]
# C01344[c]
# C01345[c]
# C01346[c]
# C01352[c]
# C01367[c]
# C01368[c]
# C01380[c]
# C01412[c]
# C01419[c]
# C01454[c]
# C01494[c]
# C01499[c]
# C01528[c]
# C01546[c]
# C01563[c]
# C01586[c]
# C01594[c]
# C01606[c]
# C01613[c]
# C01659[c]
# C01672[c]
# C01697[c]
# C01725[c]
# C01762[c]
# C01769[c]
# C01801[c]
# C01832[c]
# C01845[c]
# C01847[c]
# C01879[c]
# C01909[c]
# C01920[c]
# C01929[c]
# C01935[c]
# C01944[c]
# C01962[c]
# C02067[c]
# C02091[c]
# C02097[c]
# C02137[c]
# C02170[c]
# C02191[c]
# C02220[c]
# C02225[c]
# C02226[c]
# C02232[c]
# C02247[c]
# C02265[c]
# C02266[c]
# C02291[c]
# C02350[c]
# C02353[c]
# C02354[c]
# C02355[c]
# C02356[c]
# C02362[c]
# C02380[c]
# C02411[c]
# C02431[c]
# C02457[c]
# C02463[c]
# C02480[c]
# C02501[c]
# C02504[c]
# C02505[c]
# C02514[c]
# C02527[c]
# C02576[c]
# C02593[c]
# C02612[c]
# C02631[c]
# C02637[c]
# C02642[c]
# C02647[c]
# C02656[c]
# C02659[c]
# C02670[c]
# C02693[c]
# C02713[c]
# C02730[c]
# C02739[c]
# C02741[c]
# C02745[c]
# C02780[c]
# C02835[c]
# C02869[c]
# C02876[c]
# C02909[c]
# C02939[c]
# C02946[c]
# C02949[c]
# C02953[c]
# C02962[c]
# C02989[c]
# C02991[c]
# C02999[c]
# C03028[c]
# C03044[c]
# C03046[c]
# C03057[c]
# C03063[c]
# C03064[c]
# C03067[c]
# C03069[c]
# C03078[c]
# C03082[c]
# C03089[c]
# C03090[c]
# C03114[c]
# C03150[c]
# C03160[c]
# C03167[c]
# C03175[c]
# C03187[c]
# C03194[c]
# C03221[c]
# C03231[c]
# C03232[c]
# C03263[c]
# C03273[c]
# C03283[c]
# C03284[c]
# C03287[c]
# C03291[c]
# C03319[c]
# C03344[c]
# C03345[c]
# C03360[c]
# C03373[c]
# C03383[c]
# C03393[c]
# C03394[c]
# C03401[c]
# C03406[c]
# C03459[c]
# C03460[c]
# C03461[c]
# C03479[c]
# C03492[c]
# C03506[c]
# C03508[c]
# C03539[c]
# C03546[c]
# C03561[c]
# C03564[c]
# C03576[c]
# C03585[c]
# C03586[c]
# C03590[c]
# C03604[c]
# C03657[c]
# C03680[c]
# C03722[c]
# C03741[c]
# C03742[c]
# C03752[c]
# C03765[c]
# C03771[c]
# C03785[c]
# C03794[c]
# C03824[c]
# C03826[c]
# C03827[c]
# C03838[c]
# C03912[c]
# C03939[c]
# C03972[c]
# C03979[c]
# C04006[c]
# C04039[c]
# C04043[c]
# C04051[c]
# C04052[c]
# C04076[c]
# C04079[c]
# C04088[c]
# C04112[c]
# C04122[c]
# C04144[c]
# C04145[c]
# C04146[c]
# C04171[c]
# C04180[c]
# C04181[c]
# C04186[c]
# C04188[c]
# C04216[c]
# C04236[c]
# C04242[c]
# C04246[c]
# C04253[c]
# C04257[c]
# C04272[c]
# C04281[c]
# C04282[c]
# C04294[c]
# C04295[c]
# C04302[c]
# C04327[c]
# C04332[c]
# C04348[c]
# C04349[c]
# C04352[c]
# C04376[c]
# C04377[c]
# C04390[c]
# C04405[c]
# C04411[c]
# C04421[c]
# C04425[c]
# C04442[c]
# C04454[c]
# C04462[c]
# C04489[c]
# C04494[c]
# C04501[c]
# C04534[c]
# C04536[c]
# C04554[c]
# C04556[c]
# C04558[c]
# C04559[c]
# C04570[c]
# C04573[c]
# C04574[c]
# C04582[c]
# C04590[c]
# C04618[c]
# C04619[c]
# C04620[c]
# C04628[c]
# C04631[c]
# C04633[c]
# C04640[c]
# C04642[c]
# C04644[c]
# C04646[c]
# C04650[c]
# C04666[c]
# C04677[c]
# C04688[c]
# C04691[c]
# C04702[c]
# C04732[c]
# C04734[c]
# C04738[c]
# C04751[c]
# C04752[c]
# C04760[c]
# C04778[c]
# C04793[c]
# C04807[c]
# C04823[c]
# C04832[c]
# C04851[c]
# C04874[c]
# C04877[c]
# C04882[c]
# C04896[c]
# C04916[c]
# C05116[c]
# C05117[c]
# C05125[c]
# C05130[c]
# C05143[c]
# C05165[c]
# C05198[c]
# C05223[c]
# C05235[c]
# C05258[c]
# C05259[c]
# C05260[c]
# C05261[c]
# C05262[c]
# C05263[c]
# C05264[c]
# C05265[c]
# C05266[c]
# C05267[c]
# C05268[c]
# C05269[c]
# C05270[c]
# C05271[c]
# C05272[c]
# C05273[c]
# C05274[c]
# C05275[c]
# C05276[c]
# C05279[c]
# C05280[c]
# C05335[c]
# C05382[c]
# C05396[c]
# C05402[c]
# C05404[c]
# C05422[c]
# C05444[c]
# C05445[c]
# C05447[c]
# C05460[c]
# C05470[c]
# C05472[c]
# C05478[c]
# C05480[c]
# C05481[c]
# C05482[c]
# C05483[c]
# C05484[c]
# C05512[c]
# C05527[c]
# C05528[c]
# C05539[c]
# C05576[c]
# C05577[c]
# C05580[c]
# C05581[c]
# C05582[c]
# C05583[c]
# C05584[c]
# C05600[c]
# C05619[c]
# C05634[c]
# C05635[c]
# C05662[c]
# C05665[c]
# C05668[c]
# C05682[c]
# C05684[c]
# C05686[c]
# C05688[c]
# C05689[c]
# C05691[c]
# C05696[c]
# C05697[c]
# C05698[c]
# C05699[c]
# C05702[c]
# C05703[c]
# C05744[c]
# C05745[c]
# C05746[c]
# C05747[c]
# C05748[c]
# C05749[c]
# C05750[c]
# C05751[c]
# C05752[c]
# C05753[c]
# C05754[c]
# C05755[c]
# C05756[c]
# C05757[c]
# C05758[c]
# C05759[c]
# C05760[c]
# C05761[c]
# C05762[c]
# C05763[c]
# C05764[c]
# C05766[c]
# C05768[c]
# C05770[c]
# C05772[c]
# C05773[c]
# C05775[c]
# C05778[c]
# C05813[c]
# C05814[c]
# C05817[c]
# C05819[c]
# C05821[c]
# C05822[c]
# C05823[c]
# C05824[c]
# C05827[c]
# C05828[c]
# C05838[c]
# C05839[c]
# C05840[c]
# C05841[c]
# C05847[c]
# C05892[c]
# C05893[c]
# C05897[c]
# C05898[c]
# C05921[c]
# C05922[c]
# C05923[c]
# C05924[c]
# C05931[c]
# C05932[c]
# C05933[c]
# C05936[c]
# C05938[c]
# C05946[c]
# C05947[c]
# C05979[c]
# C05984[c]
# C05985[c]
# C05998[c]
# C06000[c]
# C06001[c]
# C06002[c]
# C06006[c]
# C06007[c]
# C06010[c]
# C06017[c]
# C06019[c]
# C06022[c]
# C06028[c]
# C06032[c]
# C06054[c]
# C06055[c]
# C06056[c]
# C06098[c]
# C06102[c]
# C06103[c]
# C06142[c]
# C06153[c]
# C06156[c]
# C06193[c]
# C06194[c]
# C06196[c]
# C06215[c]
# C06232[c]
# C06240[c]
# C06319[c]
# C06322[c]
# C06376[c]
# C06377[c]
# C06399[c]
# C06407[c]
# C06408[c]
# C06416[c]
# C06473[c]
# C06503[c]
# C06507[c]
# C06508[c]
# C06510[c]
# C06577[c]
# C06578[c]
# C06579[c]
# C06580[c]
# C06599[c]
# C06600[c]
# C06611[c]
# C06612[c]
# C06613[c]
# C06614[c]
# C06615[c]
# C06620[c]
# C06625[c]
# C06672[c]
# C06714[c]
# C06715[c]
# C06754[c]
# C06755[c]
# C06758[c]
# C06760[c]
# C06892[c]
# C06893[c]
# C06899[c]
# C07086[c]
# C07090[c]
# C07118[c]
# C07209[c]
# C07211[c]
# C07214[c]
# C07215[c]
# C07303[c]
# C07478[c]
# C07490[c]
# C07635[c]
# C07645[c]
# C07646[c]
# C07648[c]
# C07649[c]
# C08276[c]
# C08325[c]
# C08334[c]
# C08353[c]
# C09804[c]
# C09811[c]
# C09812[c]
# C09813[c]
# C09815[c]
# C09817[c]
# C09818[c]
# C09819[c]
# C09820[c]
# C09822[c]
# C09823[c]
# C09848[c]
# C09849[c]
# C10682[c]
# C11038[c]
# C11039[c]
# C11062[c]
# C11142[c]
# C11143[c]
# C11145[c]
# C11150[c]
# C11355[c]
# C11384[c]
# C11386[c]
# C11434[c]
# C11435[c]
# C11436[c]
# C11437[c]
# C11453[c]
# C11499[c]
# C11536[c]
# C11537[c]
# C11538[c]
# C11542[c]
# C11545[c]
# C11736[c]
# C11811[c]
# C11829[c]
# C11830[c]
# C11831[c]
# C11838[c]
# C11903[c]
# C11904[c]
# C11907[c]
# C11908[c]
# C11909[c]
# C11910[c]
# C11922[c]
# C11924[c]
# C11925[c]
# C11928[c]
# C12147[c]
# C12203[c]
# C12213[c]
# C12214[c]
# C12215[c]
# C12318[c]
# C12324[c]
# C12348[c]
# C12350[c]
# C12354[c]
# C12355[c]
# C12356[c]
# C12366[c]
# C12379[c]
# C12441[c]
# C12455[c]
# C12739[c]
# C13952[c]
# C14089[c]
# C14090[c]
# C14099[c]
# C14143[c]
# C14144[c]
# C14145[c]
# C14463[c]
# C14602[c]
# C14604[c]
# C14610[c]
# C14818[c]
# C14819[c]
# C14899[c]
# C15532[c]
# C15547[c]
# C15556[c]
# C15602[c]
# C15603[c]
# C15606[c]
# C15613[c]
# C15651[c]
# C15667[c]
# C15672[c]
# C15673[c]
# C15699[c]
# C15700[c]
# C15767[c]
# C15809[c]
# C15974[c]
# C15976[c]
# C15978[c]
# C15996[c]
# C16153[c]
# C16155[c]
# C16159[c]
# C16219[c]
# C16220[c]
# C16221[c]
# C16242[c]
# C16243[c]
# C16272[c]
# C16273[c]
# C16330[c]
# C16331[c]
# C16334[c]
# C16335[c]
# C16338[c]
# C16339[c]
# C16348[c]
# C16361[c]
# C16390[c]
# C16391[c]
# C16392[c]
# C16393[c]
# C16461[c]
# C16462[c]
# C16463[c]
# C16466[c]
# C16468[c]
# C16469[c]
# C16470[c]
# C16471[c]
# C16474[c]
# C16476[c]
# C16502[c]
# C16519[c]
# C16551[c]
# C16565[c]
# C16579[c]
# C16583[c]
# C16586[c]
# C16587[c]
# C16588[c]
# C16589[c]
# C16591[c]
# C16595[c]
# C16596[c]
# C16597[c]
# C16598[c]
# C16600[c]
# C16614[c]
# C16615[c]
# C16618[c]
# C16619[c]
# C16633[c]
# C16634[c]
# C16635[c]
# C16637[c]
# C16639[c]
# C16675[c]
# C16688[c]
# C16698[c]
# C16826[c]
# C17010[c]
# C17210[c]
# C17212[c]
# C17214[c]
# C17215[c]
# C17218[c]
# C17219[c]
# C17222[c]
# C17223[c]
# C17226[c]
# C17227[c]
# C17230[c]
# C17231[c]
# C17343[c]
# C17345[c]
# C17346[c]
# C17401[c]
# C17556[c]
# C17622[c]
# C17949[c]
# C17952[c]
# C17962[c]
# C18026[c]
# C18076[c]
# C18091[c]
# C18096[c]
# C18167[c]
# C18237[c]
# C18239[c]
# C18321[c]
# C18324[c]
# C18351[c]
# C18796[c]
# C18902[c]
# C19673[c]
# C19694[c]
# C19725[c]
# C19730[c]
# C19731[c]
# C19745[c]
# C19845[c]
# C19846[c]
# C19847[c]
# C19848[c]
# C19852[c]
# C19871[c]
# C19891[c]
# C19944[c]
# C19945[c]
# C19975[c]
# C20062[c]
# C20199[c]
# C20238[c]
# C20239[c]
# C20246[c]
# C20247[c]
# C20248[c]
# C20251[c]
# C20252[c]
# C20258[c]
# C20267[c]
# C20276[c]
# C20327[c]
# C20357[c]
# C20359[c]
# C20372[c]
# C20373[c]
# C20374[c]
# C20375[c]
# C20376[c]
# C20377[c]
# C20378[c]
# C20386[c]
# C20395[c]
# C20396[c]
# C20420[c]
# C20421[c]
# C20422[c]
# C20447[c]
# C20638[c]
# C20641[c]
# C20654[c]
# C20657[c]
# C20668[c]
# C20748[c]
# C20750[c]
# C20773[c]
# C20781[c]

# %%
model.metabolites.index('C20797[c]')  # Index of first missing metabolite is 1205
# Out:
# 1205

# %%
# Find the last missing metabolites after updating code for the class, Rerun the whole search later for the publication
for metabolite in model.metabolites[1205:]:
    metab_data = metab_data_container(metabolite)
    metabolite_data_containers.append(metab_data)
    
for item in metabolite_data_containers:
    data = item.get_id_and_smiles()
    metabolite_id_list.append(data[0])
    smiles_list.append(data[1])
    
print(metabolite_id_list)
print(smiles_list)
# Out:
# WARNING [bioservices.KEGG:596]:  status is not ok with Not Found
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Not Found
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Bad Request
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# ['C00001[c]', 'C00002[c]', 'C00003[c]', 'C00004[c]', 'C00005[c]', 'C00006[c]', 'C00007[c]', 'C00008[c]', 'C00009[c]', 'C00010[c]', 'C00011[c]', 'C00013[c]', 'C00014[c]', 'C00015[c]', 'C00016[c]', 'C00018[c]', 'C00019[c]', 'C00020[c]', 'C00021[c]', 'C00022[c]', 'C00024[c]', 'C00025[c]', 'C00026[c]', 'C00027[c]', 'C00029[c]', 'C00031[c]', 'C00032[c]', 'C00033[c]', 'C00035[c]', 'C00036[c]', 'C00037[c]', 'C00041[c]', 'C00042[c]', 'C00043[c]', 'C00044[c]', 'C00047[c]', 'C00048[c]', 'C00049[c]', 'C00051[c]', 'C00052[c]', 'C00053[c]', 'C00054[c]', 'C00055[c]', 'C00058[c]', 'C00059[c]', 'C00061[c]', 'C00062[c]', 'C00063[c]', 'C00064[c]', 'C00065[c]', 'C00067[c]', 'C00068[c]', 'C00072[c]', 'C00073[c]', 'C00074[c]', 'C00075[c]', 'C00077[c]', 'C00078[c]', 'C00079[c]', 'C00080[c]', 'C00081[c]', 'C00082[c]', 'C00083[c]', 'C00084[c]', 'C00085[c]', 'C00086[c]', 'C00088[c]', 'C00089[c]', 'C00091[c]', 'C00092[c]', 'C00093[c]', 'C00094[c]', 'C00095[c]', 'C00096[c]', 'C00097[c]', 'C00099[c]', 'C00100[c]', 'C00101[c]', 'C00103[c]', 'C00104[c]', 'C00105[c]', 'C00106[c]', 'C00108[c]', 'C00109[c]', 'C00111[c]', 'C00112[c]', 'C00114[c]', 'C00116[c]', 'C00117[c]', 'C00118[c]', 'C00119[c]', 'C00120[c]', 'C00121[c]', 'C00122[c]', 'C00123[c]', 'C00124[c]', 'C00127[c]', 'C00129[c]', 'C00130[c]', 'C00131[c]', 'C00132[c]', 'C00133[c]', 'C00134[c]', 'C00135[c]', 'C00136[c]', 'C00137[c]', 'C00138[c]', 'C00139[c]', 'C00140[c]', 'C00141[c]', 'C00143[c]', 'C00144[c]', 'C00147[c]', 'C00148[c]', 'C00149[c]', 'C00152[c]', 'C00153[c]', 'C00154[c]', 'C00155[c]', 'C00156[c]', 'C00158[c]', 'C00159[c]', 'C00160[c]', 'C00163[c]', 'C00164[c]', 'C00166[c]', 'C00167[c]', 'C00168[c]', 'C00169[c]', 'C00170[c]', 'C00178[c]', 'C00179[c]', 'C00180[c]', 'C00181[c]', 'C00183[c]', 'C00184[c]', 'C00185[c]', 'C00186[c]', 'C00188[c]', 'C00189[c]', 'C00190[c]', 'C00191[c]', 'C00194[c]', 'C00196[c]', 'C00197[c]', 'C00198[c]', 'C00199[c]', 'C00203[c]', 'C00204[c]', 'C00206[c]', 'C00207[c]', 'C00208[c]', 'C00209[c]', 'C00212[c]', 'C00213[c]', 'C00214[c]', 'C00217[c]', 'C00221[c]', 'C00222[c]', 'C00223[c]', 'C00224[c]', 'C00227[c]', 'C00229[c]', 'C00231[c]', 'C00232[c]', 'C00233[c]', 'C00234[c]', 'C00235[c]', 'C00236[c]', 'C00237[c]', 'C00239[c]', 'C00242[c]', 'C00244[c]', 'C00245[c]', 'C00246[c]', 'C00248[c]', 'C00249[c]', 'C00250[c]', 'C00251[c]', 'C00252[c]', 'C00253[c]', 'C00254[c]', 'C00255[c]', 'C00256[c]', 'C00257[c]', 'C00258[c]', 'C00261[c]', 'C00262[c]', 'C00263[c]', 'C00266[c]', 'C00267[c]', 'C00272[c]', 'C00275[c]', 'C00279[c]', 'C00280[c]', 'C00282[c]', 'C00283[c]', 'C00286[c]', 'C00288[c]', 'C00294[c]', 'C00295[c]', 'C00299[c]', 'C00301[c]', 'C00302[c]', 'C00310[c]', 'C00311[c]', 'C00312[c]', 'C00313[c]', 'C00314[c]', 'C00315[c]', 'C00318[c]', 'C00320[c]', 'C00322[c]', 'C00323[c]', 'C00327[c]', 'C00330[c]', 'C00331[c]', 'C00332[c]', 'C00334[c]', 'C00337[c]', 'C00341[c]', 'C00342[c]', 'C00343[c]', 'C00345[c]', 'C00349[c]', 'C00352[c]', 'C00353[c]', 'C00354[c]', 'C00356[c]', 'C00357[c]', 'C00360[c]', 'C00361[c]', 'C00362[c]', 'C00363[c]', 'C00364[c]', 'C00365[c]', 'C00366[c]', 'C00376[c]', 'C00378[c]', 'C00380[c]', 'C00385[c]', 'C00387[c]', 'C00390[c]', 'C00399[c]', 'C00402[c]', 'C00406[c]', 'C00407[c]', 'C00409[c]', 'C00411[c]', 'C00414[c]', 'C00415[c]', 'C00417[c]', 'C00423[c]', 'C00424[c]', 'C00430[c]', 'C00431[c]', 'C00433[c]', 'C00436[c]', 'C00437[c]', 'C00438[c]', 'C00440[c]', 'C00441[c]', 'C00445[c]', 'C00446[c]', 'C00447[c]', 'C00448[c]', 'C00455[c]', 'C00458[c]', 'C00459[c]', 'C00460[c]', 'C00463[c]', 'C00468[c]', 'C00469[c]', 'C00473[c]', 'C00475[c]', 'C00479[c]', 'C00482[c]', 'C00486[c]', 'C00489[c]', 'C00490[c]', 'C00491[c]', 'C00492[c]', 'C00493[c]', 'C00497[c]', 'C00498[c]', 'C00499[c]', 'C00500[c]', 'C00502[c]', 'C00503[c]', 'C00504[c]', 'C00506[c]', 'C00507[c]', 'C00511[c]', 'C00512[c]', 'C00522[c]', 'C00526[c]', 'C00527[c]', 'C00531[c]', 'C00533[c]', 'C00535[c]', 'C00536[c]', 'C00540[c]', 'C00542[c]', 'C00546[c]', 'C00552[c]', 'C00555[c]', 'C00559[c]', 'C00561[ ...
# ['O', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)N', 'C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)([O-])OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O)C(=O)N', 'C1C=CN(C=C1C(=O)N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O', 'C1C=CN(C=C1C(=O)N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)OP(=O)(O)O)O)O)O', 'C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)OP(=O)(O)O)O)O)O)C(=O)N', 'O=O', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O)N', 'OP(=O)(O)O', 'CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCS)O', 'C(=O)=O', '', 'N', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)O)O)O', 'CC1=CC2=C(C=C1C)N(C3=NC(=O)NC(=O)C3=N2)CC(C(C(COP(=O)(O)OP(=O)(O)OCC4C(C(C(O4)N5C=NC6=C(N=CN=C65)N)O)O)O)O)O', 'CC1=NC=C(C(=C1O)C=O)COP(=O)(O)O', 'C[S+](CCC(C(=O)[O-])N)CC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)O', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)O)O)N', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)CSCCC(C(=O)O)N)O)O)N', 'CC(=O)C(=O)O', 'CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O', 'C(CC(=O)O)C(C(=O)O)N', 'C(CC(=O)O)C(=O)C(=O)O', 'OO', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(C(O3)CO)O)O)O)O)O', 'C(C1C(C(C(C(O1)O)O)O)O)O', 'CC1=C(C2=CC3=C(C(=C([N-]3)C=C4C(=C(C(=N4)C=C5C(=C(C(=N5)C=C1[N-]2)C)C=C)C)C=C)C)CCC(=O)O)CCC(=O)O.[Fe+2]', 'CC(=O)O', 'C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O)N=C(NC2=O)N', 'C(C(=O)C(=O)O)C(=O)O', 'C(C(=O)O)N', 'CC(C(=O)O)N', 'C(CC(=O)O)C(=O)O', 'CC(=O)NC1C(C(C(OC1OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)CO)O)O', 'C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)N=C(NC2=O)N', 'C(CCN)CC(C(=O)O)N', 'C(=O)C(=O)O', 'C(C(C(=O)O)N)C(=O)O', 'C(CC(=O)NC(CS)C(=O)NCC(=O)O)C(C(=O)O)N', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(C(O3)CO)O)O)O)O)O', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OS(=O)(=O)O)OP(=O)(O)O)O)N', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)OP(=O)(O)O)O)N', 'C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)O)O)O', 'C(=O)O', 'OS(=O)(=O)O', 'CC1=CC2=C(C=C1C)N(C3=NC(=O)NC(=O)C3=N2)CC(C(C(COP(=O)(O)O)O)O)O', 'C(CC(C(=O)O)N)CN=C(N)N', 'C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O', 'C(CC(=O)N)C(C(=O)O)N', 'C(C(C(=O)O)N)O', 'C=O', 'CC1=C(SC=[N+]1CC2=CN=C(N=C2N)C)CCOP(=O)(O)OP(=O)(O)O', 'C(C(C1C(=C(C(=O)O1)O)O)O)O', 'CSCCC(C(=O)O)N', 'C=C(C(=O)O)OP(=O)(O)O', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O', 'C(CC(C(=O)O)N)CN', 'C1=CC=C2C(=C1)C(=CN2)CC(C(=O)O)N', 'C1=CC=C(C=C1)CC(C(=O)O)N', '[H+]', 'C1=NC2=C(C(=O)N1)N=CN2C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O', 'C1=CC(=CC=C1CC(C(=O)O)N)O', 'CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CC(=O)O)O', 'CC=O', 'C(C1C(C(C(O1)(CO)O)O)O)OP(=O)(O)O', 'C(=O)(N)N', 'N(=O)[O-]', 'C(C1C(C(C(C(O1)OC2(C(C(C(O2)CO)O)O)CO)O)O)O)O', 'CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CCC(=O)O)O', 'C(C1C(C(C(C(O1)O)O)O)O)OP(=O)(O)O', 'C(C(COP(=O)(O)O)O)O', 'OS(=O)O', 'C(C1C(C(C(O1)(CO)O)O)O)O', 'C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OC4C(C(C(C(O4)CO)O)O)O)O)O)N=C(NC2=O)N', 'C(C(C(=O)O)N)S', 'C(CN)C(=O)O', 'CCC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O', 'C1C(NC2=C(N1)N=C(NC2=O)N)CNC3=CC=C(C=C3)C(=O)NC(CCC(=O)O)C(=O)O', 'C(C1C(C(C(C(O1)OP(=O)(O)O)O)O)O)O', 'C1=NC2=C(C(=O)N1)N=CN2C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)O)O)O', 'C1=CNC(=O)NC1=O', 'C1=CC=C(C(=C1)C(=O)[O-])N', 'CCC(=O)C(=O)[O-]', 'C(C(=O)COP(=O)(O)O)O', 'C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)O)O)O', 'C[N+](C)(C)CCO', 'C(C(CO)O)O', 'C(C(C(C(C=O)O)O)O)OP(=O)(O)O', 'C(C(C=O)O)OP(=O)(O)O', 'C(C1C(C(C(O1)OP(=O)(O)OP(=O)(O)O)O)O)OP(=O)(O)O', 'C1C2C(C(S1)CCCCC(=O)O)NC(=O)N2', 'C1C(C(C(C(O1)O)O)O)O', 'C(=CC(=O)O)C(=O)O', 'CC(C)CC(C(=O)O)N', 'C(C1C(C(C(C(O1)O)O)O)O ...

# %%
print(metabolite_id_list)
# Out:
# ['C00001[c]', 'C00002[c]', 'C00003[c]', 'C00004[c]', 'C00005[c]', 'C00006[c]', 'C00007[c]', 'C00008[c]', 'C00009[c]', 'C00010[c]', 'C00011[c]', 'C00013[c]', 'C00014[c]', 'C00015[c]', 'C00016[c]', 'C00018[c]', 'C00019[c]', 'C00020[c]', 'C00021[c]', 'C00022[c]', 'C00024[c]', 'C00025[c]', 'C00026[c]', 'C00027[c]', 'C00029[c]', 'C00031[c]', 'C00032[c]', 'C00033[c]', 'C00035[c]', 'C00036[c]', 'C00037[c]', 'C00041[c]', 'C00042[c]', 'C00043[c]', 'C00044[c]', 'C00047[c]', 'C00048[c]', 'C00049[c]', 'C00051[c]', 'C00052[c]', 'C00053[c]', 'C00054[c]', 'C00055[c]', 'C00058[c]', 'C00059[c]', 'C00061[c]', 'C00062[c]', 'C00063[c]', 'C00064[c]', 'C00065[c]', 'C00067[c]', 'C00068[c]', 'C00072[c]', 'C00073[c]', 'C00074[c]', 'C00075[c]', 'C00077[c]', 'C00078[c]', 'C00079[c]', 'C00080[c]', 'C00081[c]', 'C00082[c]', 'C00083[c]', 'C00084[c]', 'C00085[c]', 'C00086[c]', 'C00088[c]', 'C00089[c]', 'C00091[c]', 'C00092[c]', 'C00093[c]', 'C00094[c]', 'C00095[c]', 'C00096[c]', 'C00097[c]', 'C00099[c]', 'C00100[c]', 'C00101[c]', 'C00103[c]', 'C00104[c]', 'C00105[c]', 'C00106[c]', 'C00108[c]', 'C00109[c]', 'C00111[c]', 'C00112[c]', 'C00114[c]', 'C00116[c]', 'C00117[c]', 'C00118[c]', 'C00119[c]', 'C00120[c]', 'C00121[c]', 'C00122[c]', 'C00123[c]', 'C00124[c]', 'C00127[c]', 'C00129[c]', 'C00130[c]', 'C00131[c]', 'C00132[c]', 'C00133[c]', 'C00134[c]', 'C00135[c]', 'C00136[c]', 'C00137[c]', 'C00138[c]', 'C00139[c]', 'C00140[c]', 'C00141[c]', 'C00143[c]', 'C00144[c]', 'C00147[c]', 'C00148[c]', 'C00149[c]', 'C00152[c]', 'C00153[c]', 'C00154[c]', 'C00155[c]', 'C00156[c]', 'C00158[c]', 'C00159[c]', 'C00160[c]', 'C00163[c]', 'C00164[c]', 'C00166[c]', 'C00167[c]', 'C00168[c]', 'C00169[c]', 'C00170[c]', 'C00178[c]', 'C00179[c]', 'C00180[c]', 'C00181[c]', 'C00183[c]', 'C00184[c]', 'C00185[c]', 'C00186[c]', 'C00188[c]', 'C00189[c]', 'C00190[c]', 'C00191[c]', 'C00194[c]', 'C00196[c]', 'C00197[c]', 'C00198[c]', 'C00199[c]', 'C00203[c]', 'C00204[c]', 'C00206[c]', 'C00207[c]', 'C00208[c]', 'C00209[c]', 'C00212[c]', 'C00213[c]', 'C00214[c]', 'C00217[c]', 'C00221[c]', 'C00222[c]', 'C00223[c]', 'C00224[c]', 'C00227[c]', 'C00229[c]', 'C00231[c]', 'C00232[c]', 'C00233[c]', 'C00234[c]', 'C00235[c]', 'C00236[c]', 'C00237[c]', 'C00239[c]', 'C00242[c]', 'C00244[c]', 'C00245[c]', 'C00246[c]', 'C00248[c]', 'C00249[c]', 'C00250[c]', 'C00251[c]', 'C00252[c]', 'C00253[c]', 'C00254[c]', 'C00255[c]', 'C00256[c]', 'C00257[c]', 'C00258[c]', 'C00261[c]', 'C00262[c]', 'C00263[c]', 'C00266[c]', 'C00267[c]', 'C00272[c]', 'C00275[c]', 'C00279[c]', 'C00280[c]', 'C00282[c]', 'C00283[c]', 'C00286[c]', 'C00288[c]', 'C00294[c]', 'C00295[c]', 'C00299[c]', 'C00301[c]', 'C00302[c]', 'C00310[c]', 'C00311[c]', 'C00312[c]', 'C00313[c]', 'C00314[c]', 'C00315[c]', 'C00318[c]', 'C00320[c]', 'C00322[c]', 'C00323[c]', 'C00327[c]', 'C00330[c]', 'C00331[c]', 'C00332[c]', 'C00334[c]', 'C00337[c]', 'C00341[c]', 'C00342[c]', 'C00343[c]', 'C00345[c]', 'C00349[c]', 'C00352[c]', 'C00353[c]', 'C00354[c]', 'C00356[c]', 'C00357[c]', 'C00360[c]', 'C00361[c]', 'C00362[c]', 'C00363[c]', 'C00364[c]', 'C00365[c]', 'C00366[c]', 'C00376[c]', 'C00378[c]', 'C00380[c]', 'C00385[c]', 'C00387[c]', 'C00390[c]', 'C00399[c]', 'C00402[c]', 'C00406[c]', 'C00407[c]', 'C00409[c]', 'C00411[c]', 'C00414[c]', 'C00415[c]', 'C00417[c]', 'C00423[c]', 'C00424[c]', 'C00430[c]', 'C00431[c]', 'C00433[c]', 'C00436[c]', 'C00437[c]', 'C00438[c]', 'C00440[c]', 'C00441[c]', 'C00445[c]', 'C00446[c]', 'C00447[c]', 'C00448[c]', 'C00455[c]', 'C00458[c]', 'C00459[c]', 'C00460[c]', 'C00463[c]', 'C00468[c]', 'C00469[c]', 'C00473[c]', 'C00475[c]', 'C00479[c]', 'C00482[c]', 'C00486[c]', 'C00489[c]', 'C00490[c]', 'C00491[c]', 'C00492[c]', 'C00493[c]', 'C00497[c]', 'C00498[c]', 'C00499[c]', 'C00500[c]', 'C00502[c]', 'C00503[c]', 'C00504[c]', 'C00506[c]', 'C00507[c]', 'C00511[c]', 'C00512[c]', 'C00522[c]', 'C00526[c]', 'C00527[c]', 'C00531[c]', 'C00533[c]', 'C00535[c]', 'C00536[c]', 'C00540[c]', 'C00542[c]', 'C00546[c]', 'C00552[c]', 'C00555[c]', 'C00559[c]', 'C00561[ ...

# %%
print(smiles_list)
# Out:
# ['O', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)N', 'C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)([O-])OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O)C(=O)N', 'C1C=CN(C=C1C(=O)N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O', 'C1C=CN(C=C1C(=O)N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)OP(=O)(O)O)O)O)O', 'C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)OP(=O)(O)O)O)O)O)C(=O)N', 'O=O', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O)N', 'OP(=O)(O)O', 'CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCS)O', 'C(=O)=O', '', 'N', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)O)O)O', 'CC1=CC2=C(C=C1C)N(C3=NC(=O)NC(=O)C3=N2)CC(C(C(COP(=O)(O)OP(=O)(O)OCC4C(C(C(O4)N5C=NC6=C(N=CN=C65)N)O)O)O)O)O', 'CC1=NC=C(C(=C1O)C=O)COP(=O)(O)O', 'C[S+](CCC(C(=O)[O-])N)CC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)O', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)O)O)N', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)CSCCC(C(=O)O)N)O)O)N', 'CC(=O)C(=O)O', 'CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O', 'C(CC(=O)O)C(C(=O)O)N', 'C(CC(=O)O)C(=O)C(=O)O', 'OO', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(C(O3)CO)O)O)O)O)O', 'C(C1C(C(C(C(O1)O)O)O)O)O', 'CC1=C(C2=CC3=C(C(=C([N-]3)C=C4C(=C(C(=N4)C=C5C(=C(C(=N5)C=C1[N-]2)C)C=C)C)C=C)C)CCC(=O)O)CCC(=O)O.[Fe+2]', 'CC(=O)O', 'C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O)N=C(NC2=O)N', 'C(C(=O)C(=O)O)C(=O)O', 'C(C(=O)O)N', 'CC(C(=O)O)N', 'C(CC(=O)O)C(=O)O', 'CC(=O)NC1C(C(C(OC1OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)CO)O)O', 'C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)N=C(NC2=O)N', 'C(CCN)CC(C(=O)O)N', 'C(=O)C(=O)O', 'C(C(C(=O)O)N)C(=O)O', 'C(CC(=O)NC(CS)C(=O)NCC(=O)O)C(C(=O)O)N', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(C(O3)CO)O)O)O)O)O', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OS(=O)(=O)O)OP(=O)(O)O)O)N', 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)OP(=O)(O)O)O)N', 'C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)O)O)O', 'C(=O)O', 'OS(=O)(=O)O', 'CC1=CC2=C(C=C1C)N(C3=NC(=O)NC(=O)C3=N2)CC(C(C(COP(=O)(O)O)O)O)O', 'C(CC(C(=O)O)N)CN=C(N)N', 'C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O', 'C(CC(=O)N)C(C(=O)O)N', 'C(C(C(=O)O)N)O', 'C=O', 'CC1=C(SC=[N+]1CC2=CN=C(N=C2N)C)CCOP(=O)(O)OP(=O)(O)O', 'C(C(C1C(=C(C(=O)O1)O)O)O)O', 'CSCCC(C(=O)O)N', 'C=C(C(=O)O)OP(=O)(O)O', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O', 'C(CC(C(=O)O)N)CN', 'C1=CC=C2C(=C1)C(=CN2)CC(C(=O)O)N', 'C1=CC=C(C=C1)CC(C(=O)O)N', '[H+]', 'C1=NC2=C(C(=O)N1)N=CN2C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O', 'C1=CC(=CC=C1CC(C(=O)O)N)O', 'CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CC(=O)O)O', 'CC=O', 'C(C1C(C(C(O1)(CO)O)O)O)OP(=O)(O)O', 'C(=O)(N)N', 'N(=O)[O-]', 'C(C1C(C(C(C(O1)OC2(C(C(C(O2)CO)O)O)CO)O)O)O)O', 'CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CCC(=O)O)O', 'C(C1C(C(C(C(O1)O)O)O)O)OP(=O)(O)O', 'C(C(COP(=O)(O)O)O)O', 'OS(=O)O', 'C(C1C(C(C(O1)(CO)O)O)O)O', 'C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OC4C(C(C(C(O4)CO)O)O)O)O)O)N=C(NC2=O)N', 'C(C(C(=O)O)N)S', 'C(CN)C(=O)O', 'CCC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O', 'C1C(NC2=C(N1)N=C(NC2=O)N)CNC3=CC=C(C=C3)C(=O)NC(CCC(=O)O)C(=O)O', 'C(C1C(C(C(C(O1)OP(=O)(O)O)O)O)O)O', 'C1=NC2=C(C(=O)N1)N=CN2C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O', 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)O)O)O', 'C1=CNC(=O)NC1=O', 'C1=CC=C(C(=C1)C(=O)[O-])N', 'CCC(=O)C(=O)[O-]', 'C(C(=O)COP(=O)(O)O)O', 'C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)O)O)O', 'C[N+](C)(C)CCO', 'C(C(CO)O)O', 'C(C(C(C(C=O)O)O)O)OP(=O)(O)O', 'C(C(C=O)O)OP(=O)(O)O', 'C(C1C(C(C(O1)OP(=O)(O)OP(=O)(O)O)O)O)OP(=O)(O)O', 'C1C2C(C(S1)CCCCC(=O)O)NC(=O)N2', 'C1C(C(C(C(O1)O)O)O)O', 'C(=CC(=O)O)C(=O)O', 'CC(C)CC(C(=O)O)N', 'C(C1C(C(C(C(O1)O)O)O)O ...

# %%
print(len(smiles_list))
print(len(metabolite_id_list))
print(len(model.metabolites))
# Out:
# 1310
# 1310
# 1310

# %%
# Save data
import csv
with open('smiles_list.csv', 'w') as outfile:
    wr = csv.writer(outfile)
    wr.writerow(smiles_list)
    outfile.close()
    
with open('metabolite_id_list.csv', 'w') as outfile:
    wr = csv.writer(outfile)
    wr.writerow(metabolite_id_list)
    outfile.close()

# %%
import pickle

def load_data():
    try:
        with open("metabolite_data.dat") as f:
            data = pickle.load(f)
            return data
    except:
        metabolite_data_containers = []

def save_data(data):
    with open("metabolite_data.dat", "wb") as f:
        pickle.dump(data, f)

# %%
save_data(metabolite_data_containers)
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# Input In [160], in <cell line: 1>()
# ----> 1 save_data(metabolite_data_containers)
#
# Input In [159], in save_data(data)
#      11 def save_data(data):
#      12     with open("metabolite_data.dat", "wb") as f:
# ---> 13         pickle.dump(data, f)
#
# PicklingError: Can't pickle <class '__main__.metab_data_container'>: it's not the same object as __main__.metab_data_container

# %%
testdata = load_data()
print(testdata)
# Out:
# None

# %%
# Fixes some metabolite names
metabolites = []
for metabolite in model.metabolites:
    if '_e' in metabolite.id:
        metabolite.id = metabolite.id.replace('_e', '')
    metabolites.append(metabolite.id)

curated_metabolites = []  # List of KEGG ids for metabolites in the model
for metabolite in metabolites:
    if  metabolite[0:2] in ['C0','C1','C2']:
        metabolite = metabolite.rstrip('[c]').rstrip('[e]')  # Removes compartment identifiers
        curated_metabolites.append(metabolite)

# %%
import requests

# One method to obtain SMILES by PubChem API using the website
def get_smiles(name):
    # smiles = redis_cli.get(name)
    # if smiles is None:
    try :
        url = 'https://pubchem.ncbi.nlm.nih.gov/rest/pug/compound/name/%s/property/CanonicalSMILES/TXT' % name
        req = requests.get(url)
        if req.status_code != 200:
            smiles = None
            return False
        else:
            smiles = req.content.splitlines()[0].decode()
            name_smiles[name] = smiles
            print('SMILES for %s: %s' %(name, smiles))
            return True
        # redis_cli.set(name, smiles, ex=None)

        # print smiles
    except :
        smiles = None
        return False


    

    
testnames = ['glucose', 'oxygen', 'water', 'palmitic acid']    
for name in testnames:
    get_smiles(name)
    
# Working!
# Out:
# SMILES for glucose: C(C1C(C(C(C(O1)O)O)O)O)O
# SMILES for oxygen: O=O
# SMILES for water: O
# SMILES for palmitic acid: CCCCCCCCCCCCCCCC(=O)O

# %%
print(name_smiles)
# Out:
# {'glucose': 'C(C1C(C(C(C(O1)O)O)O)O)O', 'oxygen': 'O=O', 'water': 'O', 'palmitic acid': 'CCCCCCCCCCCCCCCC(=O)O'}

# %%
# Get metabolite names from KEGG
from bioservices import *

kegg_con = KEGG()
metnames = []
missing_metnames = []
for metabolite in curated_metabolites:
    try:
        kegg_con = KEGG()
        metname = kegg_con.parse(kegg_con.get(metabolite))['NAME']
        metnames.append(metname)
    except: missing_metnames.append(metabolite)
        
print(len(curated_metabolites))
print(len(metnames))
print(len(missing_metnames))
# Out:
# WARNING [bioservices.KEGG:596]:  status is not ok with Not Found
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:596]:  status is not ok with Not Found
# WARNING [bioservices.KEGG:1179]:  Could not parse the entry correctly.
# WARNING [bioservices.KEGG:130]:  The URL (http://rest.kegg.jp) provided cannot be reached.
# 1298
# 1296
# 2

# %%
curated_metabolites
# Out:
# ['C00001',
#  'C00002',
#  'C00003',
#  'C00004',
#  'C00005',
#  'C00006',
#  'C00007',
#  'C00008',
#  'C00009',
#  'C00010',
#  'C00011',
#  'C00013',
#  'C00014',
#  'C00015',
#  'C00016',
#  'C00018',
#  'C00019',
#  'C00020',
#  'C00021',
#  'C00022',
#  'C00024',
#  'C00025',
#  'C00026',
#  'C00027',
#  'C00029',
#  'C00031',
#  'C00032',
#  'C00033',
#  'C00035',
#  'C00036',
#  'C00037',
#  'C00041',
#  'C00042',
#  'C00043',
#  'C00044',
#  'C00047',
#  'C00048',
#  'C00049',
#  'C00051',
#  'C00052',
#  'C00053',
#  'C00054',
#  'C00055',
#  'C00058',
#  'C00059',
#  'C00061',
#  'C00062',
#  'C00063',
#  'C00064',
#  'C00065',
#  'C00067',
#  'C00068',
#  'C00072',
#  'C00073',
#  'C00074',
#  'C00075',
#  'C00077',
#  'C00078',
#  'C00079',
#  'C00080',
#  'C00081',
#  'C00082',
#  'C00083',
#  'C00084',
#  'C00085',
#  'C00086',
#  'C00088',
#  'C00089',
#  'C00091',
#  'C00092',
#  'C00093',
#  'C00094',
#  'C00095',
#  'C00096',
#  'C00097',
#  'C00099',
#  'C00100',
#  'C00101',
#  'C00103',
#  'C00104',
#  'C00105',
#  'C00106',
#  'C00108',
#  'C00109',
#  'C00111',
#  'C00112',
#  'C00114',
#  'C00116',
#  'C00117',
#  'C00118',
#  'C00119',
#  'C00120',
#  'C00121',
#  'C00122',
#  'C00123',
#  'C00124',
#  'C00127',
#  'C00129',
#  'C00130',
#  'C00131',
#  'C00132',
#  'C00133',
#  'C00134',
#  'C00135',
#  'C00136',
#  'C00137',
#  'C00138',
#  'C00139',
#  'C00140',
#  'C00141',
#  'C00143',
#  'C00144',
#  'C00147',
#  'C00148',
#  'C00149',
#  'C00152',
#  'C00153',
#  'C00154',
#  'C00155',
#  'C00156',
#  'C00158',
#  'C00159',
#  'C00160',
#  'C00163',
#  'C00164',
#  'C00166',
#  'C00167',
#  'C00168',
#  'C00169',
#  'C00170',
#  'C00178',
#  'C00179',
#  'C00180',
#  'C00181',
#  'C00183',
#  'C00184',
#  'C00185',
#  'C00186',
#  'C00188',
#  'C00189',
#  'C00190',
#  'C00191',
#  'C00194',
#  'C00196',
#  'C00197',
#  'C00198',
#  'C00199',
#  'C00203',
#  'C00204',
#  'C00206',
#  'C00207',
#  'C00208',
#  'C00209',
#  'C00212',
#  'C00213',
#  'C00214',
#  'C00217',
#  'C00221',
#  'C00222',
#  'C00223',
#  'C00224',
#  'C00227',
#  'C00229',
#  'C00231',
#  'C00232',
#  'C00233',
#  'C00234',
#  'C00235',
#  'C00236',
#  'C00237',
#  'C00239',
#  'C00242',
#  'C00244',
#  'C00245',
#  'C00246',
#  'C00248',
#  'C00249',
#  'C00250',
#  'C00251',
#  'C00252',
#  'C00253',
#  'C00254',
#  'C00255',
#  'C00256',
#  'C00257',
#  'C00258',
#  'C00261',
#  'C00262',
#  'C00263',
#  'C00266',
#  'C00267',
#  'C00272',
#  'C00275',
#  'C00279',
#  'C00280',
#  'C00282',
#  'C00283',
#  'C00286',
#  'C00288',
#  'C00294',
#  'C00295',
#  'C00299',
#  'C00301',
#  'C00302',
#  'C00310',
#  'C00311',
#  'C00312',
#  'C00313',
#  'C00314',
#  'C00315',
#  'C00318',
#  'C00320',
#  'C00322',
#  'C00323',
#  'C00327',
#  'C00330',
#  'C00331',
#  'C00332',
#  'C00334',
#  'C00337',
#  'C00341',
#  'C00342',
#  'C00343',
#  'C00345',
#  'C00349',
#  'C00352',
#  'C00353',
#  'C00354',
#  'C00356',
#  'C00357',
#  'C00360',
#  'C00361',
#  'C00362',
#  'C00363',
#  'C00364',
#  'C00365',
#  'C00366',
#  'C00376',
#  'C00378',
#  'C00380',
#  'C00385',
#  'C00387',
#  'C00390',
#  'C00399',
#  'C00402',
#  'C00406',
#  'C00407',
#  'C00409',
#  'C00411',
#  'C00414',
#  'C00415',
#  'C00417',
#  'C00423',
#  'C00424',
#  'C00430',
#  'C00431',
#  'C00433',
#  'C00436',
#  'C00437',
#  'C00438',
#  'C00440',
#  'C00441',
#  'C00445',
#  'C00446',
#  'C00447',
#  'C00448',
#  'C00455',
#  'C00458',
#  'C00459',
#  'C00460',
#  'C00463',
#  'C00468',
#  'C00469',
#  'C00473',
#  'C00475',
#  'C00479',
#  'C00482',
#  'C00486',
#  'C00489',
#  'C00490',
#  'C00491',
#  'C00492',
#  'C00493',
#  'C00497',
#  'C00498',
#  'C00499',
#  'C00500',
#  'C00502',
#  'C00503',
#  'C00504',
#  'C00506',
#  'C00507',
#  'C00511',
#  'C00512',
#  'C00522',
#  'C00526',
#  'C00527',
#  'C00531',
#  'C00533',
#  'C00535',
#  'C00536',
#  'C00540',
#  'C00542',
#  'C00546',
#  'C00552',
#  'C00555',
#  'C00559',
#  'C00561',
#  'C00568',
#  'C00576',
#  'C00577',
#  'C00579',
#  'C00580',
#  'C00583',
#  'C00587',
#  'C00593',
#  'C00601',
#  'C00603',
#  'C00606',
#  'C00617',
#  'C00618',
#  'C00620',
#  'C00623',
#  'C00624',
#  'C00631',
#  'C00633',
#  'C00636',
#  'C00637',
#  'C00642',
#  'C00645',
#  'C00655',
#  'C00666',
#  'C00670',
#  'C00671',
#  'C00672',
#  'C00673',
#  'C00674',
#  'C00679',
#  'C00680',
#  'C00682',
#  'C00683',
#  'C00688',
#  'C00689',
#  'C00691',
#  'C00692',
#  'C00700',
#  'C00705',
#  'C00719',
#  'C00729',
#  'C00740',
#  'C00741',
#  'C00748',
#  'C00750',
#  'C00755',
#  'C00783',
#  'C00785',
#  'C00789',
#  'C00795',
#  'C00800',
#  'C00802',
#  'C00804',
#  'C00810',
#  'C00811',
#  'C00818',
#  'C00819',
#  'C00826',
#  'C00828',
#  'C00831',
#  'C00842',
#  'C00844',
#  'C00845',
#  'C00846',
#  'C00853',
#  'C00854',
#  'C00857',
#  'C00860',
#  'C00864',
#  'C00870',
#  'C00876',
#  'C00877',
#  'C00881',
#  'C00882',
#  'C00885',
#  'C00894',
#  'C00898',
#  'C00900',
#  'C00921',
#  'C00931',
#  'C00935',
#  'C00937',
#  'C00940',
#  'C00944',
#  'C00951',
#  'C00954',
#  'C00956',
#  'C00957',
#  'C00966',
#  'C00969',
#  'C00973',
#  'C00976',
#  'C00979',
#  'C00984',
#  'C00989',
#  'C00990',
#  'C00993',
#  'C01005',
#  'C01007',
#  'C01010',
#  'C01020',
#  'C01024',
#  'C01035',
#  'C01037',
#  'C01050',
#  'C01051',
#  'C01063',
#  'C01068',
#  'C01077',
#  'C01079',
#  'C01080',
#  'C01081',
#  'C01083',
#  'C01092',
#  'C01094',
#  'C01097',
#  'C01100',
#  'C01102',
#  'C01103',
#  'C01113',
#  'C01118',
#  'C01127',
#  'C01134',
#  'C01137',
#  'C01144',
#  'C01146',
#  'C01149',
#  'C01157',
#  'C01161',
#  'C01163',
#  'C01165',
#  'C01168',
#  'C01170',
#  'C01177',
#  'C01179',
#  'C01180',
#  'C01181',
#  'C01185',
#  'C01197',
#  'C01205',
#  'C01209',
#  'C01212',
#  'C01213',
#  'C01216',
#  'C01217',
#  'C01218',
#  'C01222',
#  'C01227',
#  'C01228',
#  'C01230',
#  'C01233',
#  'C01236',
#  'C01250',
#  'C01251',
#  'C01267',
#  'C01268',
#  'C01269',
#  'C01278',
#  'C01279',
#  'C01286',
#  'C01289',
#  'C01291',
#  'C01300',
#  'C01302',
#  'C01304',
#  'C01327',
#  'C01344',
#  'C01345',
#  'C01346',
#  'C01352',
#  'C01367',
#  'C01368',
#  'C01380',
#  'C01412',
#  'C01419',
#  'C01454',
#  'C01494',
#  'C01499',
#  'C01528',
#  'C01546',
#  'C01563',
#  'C01586',
#  'C01594',
#  'C01606',
#  'C01613',
#  'C01659',
#  'C01672',
#  'C01697',
#  'C01725',
#  'C01762',
#  'C01769',
#  'C01801',
#  'C01832',
#  'C01845',
#  'C01847',
#  'C01879',
#  'C01909',
#  'C01920',
#  'C01929',
#  'C01935',
#  'C01944',
#  'C01962',
#  'C02067',
#  'C02091',
#  'C02097',
#  'C02137',
#  'C02170',
#  'C02191',
#  'C02220',
#  'C02225',
#  'C02226',
#  'C02232',
#  'C02247',
#  'C02265',
#  'C02266',
#  'C02291',
#  'C02350',
#  'C02353',
#  'C02354',
#  'C02355',
#  'C02356',
#  'C02362',
#  'C02380',
#  'C02411',
#  'C02431',
#  'C02457',
#  'C02463',
#  'C02480',
#  'C02501',
#  'C02504',
#  'C02505',
#  'C02514',
#  'C02527',
#  'C02576',
#  'C02593',
#  'C02612',
#  'C02631',
#  'C02637',
#  'C02642',
#  'C02647',
#  'C02656',
#  'C02659',
#  'C02670',
#  'C02693',
#  'C02713',
#  'C02730',
#  'C02739',
#  'C02741',
#  'C02745',
#  'C02780',
#  'C02835',
#  'C02869',
#  'C02876',
#  'C02909',
#  'C02939',
#  'C02946',
#  'C02949',
#  'C02953',
#  'C02962',
#  'C02989',
#  'C02991',
#  'C02999',
#  'C03028',
#  'C03044',
#  'C03046',
#  'C03057',
#  'C03063',
#  'C03064',
#  'C03067',
#  'C03069',
#  'C03078',
#  'C03082',
#  'C03089',
#  'C03090',
#  'C03114',
#  'C03150',
#  'C03160',
#  'C03167',
#  'C03175',
#  'C03187',
#  'C03194',
#  'C03221',
#  'C03231',
#  'C03232',
#  'C03263',
#  'C03273',
#  'C03283',
#  'C03284',
#  'C03287',
#  'C03291',
#  'C03319',
#  'C03344',
#  'C03345',
#  'C03360',
#  'C03373',
#  'C03383',
#  'C03393',
#  'C03394',
#  'C03401',
#  'C03406',
#  'C03459',
#  'C03460',
#  'C03461',
#  'C03479',
#  'C03492',
#  'C03506',
#  'C03508',
#  'C03539',
#  'C03546',
#  'C03561',
#  'C03564',
#  'C03576',
#  'C03585',
#  'C03586',
#  'C03590',
#  'C03604',
#  'C03657',
#  'C03680',
#  'C03722',
#  'C03741',
#  'C03742',
#  'C03752',
#  'C03765',
#  'C03771',
#  'C03785',
#  'C03794',
#  'C03824',
#  'C03826',
#  'C03827',
#  'C03838',
#  'C03912',
#  'C03939',
#  'C03972',
#  'C03979',
#  'C04006',
#  'C04039',
#  'C04043',
#  'C04051',
#  'C04052',
#  'C04076',
#  'C04079',
#  'C04088',
#  'C04112',
#  'C04122',
#  'C04144',
#  'C04145',
#  'C04146',
#  'C04171',
#  'C04180',
#  'C04181',
#  'C04186',
#  'C04188',
#  'C04216',
#  'C04236',
#  'C04242',
#  'C04246',
#  'C04253',
#  'C04257',
#  'C04272',
#  'C04281',
#  'C04282',
#  'C04294',
#  'C04295',
#  'C04302',
#  'C04327',
#  'C04332',
#  'C04348',
#  'C04349',
#  'C04352',
#  'C04376',
#  'C04377',
#  'C04390',
#  'C04405',
#  'C04411',
#  'C04421',
#  'C04425',
#  'C04442',
#  'C04454',
#  'C04462',
#  'C04489',
#  'C04494',
#  'C04501',
#  'C04534',
#  'C04536',
#  'C04554',
#  'C04556',
#  'C04558',
#  'C04559',
#  'C04570',
#  'C04573',
#  'C04574',
#  'C04582',
#  'C04590',
#  'C04618',
#  'C04619',
#  'C04620',
#  'C04628',
#  'C04631',
#  'C04633',
#  'C04640',
#  'C04642',
#  'C04644',
#  'C04646',
#  'C04650',
#  'C04666',
#  'C04677',
#  'C04688',
#  'C04691',
#  'C04702',
#  'C04732',
#  'C04734',
#  'C04738',
#  'C04751',
#  'C04752',
#  'C04760',
#  'C04778',
#  'C04793',
#  'C04807',
#  'C04823',
#  'C04832',
#  'C04851',
#  'C04874',
#  'C04877',
#  'C04882',
#  'C04896',
#  'C04916',
#  'C05116',
#  'C05117',
#  'C05125',
#  'C05130',
#  'C05143',
#  'C05165',
#  'C05198',
#  'C05223',
#  'C05235',
#  'C05258',
#  'C05259',
#  'C05260',
#  'C05261',
#  'C05262',
#  'C05263',
#  'C05264',
#  'C05265',
#  'C05266',
#  'C05267',
#  'C05268',
#  'C05269',
#  'C05270',
#  'C05271',
#  'C05272',
#  'C05273',
#  'C05274',
#  'C05275',
#  'C05276',
#  'C05279',
#  'C05280',
#  'C05335',
#  'C05382',
#  'C05396',
#  'C05402',
#  'C05404',
#  'C05422',
#  'C05444',
#  'C05445',
#  'C05447',
#  'C05460',
#  'C05470',
#  'C05472',
#  'C05478',
#  'C05480',
#  'C05481',
#  'C05482',
#  'C05483',
#  'C05484',
#  'C05512',
#  'C05527',
#  'C05528',
#  'C05539',
#  'C05576',
#  'C05577',
#  'C05580',
#  'C05581',
#  'C05582',
#  'C05583',
#  'C05584',
#  'C05600',
#  'C05619',
#  'C05634',
#  'C05635',
#  'C05662',
#  'C05665',
#  'C05668',
#  'C05682',
#  'C05684',
#  'C05686',
#  'C05688',
#  'C05689',
#  'C05691',
#  'C05696',
#  'C05697',
#  'C05698',
#  'C05699',
#  'C05702',
#  'C05703',
#  'C05744',
#  'C05745',
#  'C05746',
#  'C05747',
#  'C05748',
#  'C05749',
#  'C05750',
#  'C05751',
#  'C05752',
#  'C05753',
#  'C05754',
#  'C05755',
#  'C05756',
#  'C05757',
#  'C05758',
#  'C05759',
#  'C05760',
#  'C05761',
#  'C05762',
#  'C05763',
#  'C05764',
#  'C05766',
#  'C05768',
#  'C05770',
#  'C05772',
#  'C05773',
#  'C05775',
#  'C05778',
#  'C05813',
#  'C05814',
#  'C05817',
#  'C05819',
#  'C05821',
#  'C05822',
#  'C05823',
#  'C05824',
#  'C05827',
#  'C05828',
#  'C05838',
#  'C05839',
#  'C05840',
#  'C05841',
#  'C05847',
#  'C05892',
#  'C05893',
#  'C05897',
#  'C05898',
#  'C05921',
#  'C05922',
#  'C05923',
#  'C05924',
#  'C05931',
#  'C05932',
#  'C05933',
#  'C05936',
#  'C05938',
#  'C05946',
#  'C05947',
#  'C05979',
#  'C05984',
#  'C05985',
#  'C05998',
#  'C06000',
#  'C06001',
#  'C06002',
#  'C06006',
#  'C06007',
#  'C06010',
#  'C06017',
#  'C06019',
#  'C06022',
#  'C06028',
#  'C06032',
#  'C06054',
#  'C06055',
#  'C06056',
#  'C06098',
#  'C06102',
#  'C06103',
#  'C06142',
#  'C06153',
#  'C06156',
#  'C06193',
#  'C06194',
#  'C06196',
#  'C06215',
#  'C06232',
#  'C06240',
#  'C06319',
#  'C06322',
#  'C06376',
#  'C06377',
#  'C06399',
#  'C06407',
#  'C06408',
#  'C06416',
#  'C06473',
#  'C06503',
#  'C06507',
#  'C06508',
#  'C06510',
#  'C06577',
#  'C06578',
#  'C06579',
#  'C06580',
#  'C06599',
#  'C06600',
#  'C06611',
#  'C06612',
#  'C06613',
#  'C06614',
#  'C06615',
#  'C06620',
#  'C06625',
#  'C06672',
#  'C06714',
#  'C06715',
#  'C06754',
#  'C06755',
#  'C06758',
#  'C06760',
#  'C06892',
#  'C06893',
#  'C06899',
#  'C07086',
#  'C07090',
#  'C07118',
#  'C07209',
#  'C07211',
#  'C07214',
#  'C07215',
#  'C07303',
#  'C07478',
#  'C07490',
#  'C07635',
#  'C07645',
#  'C07646',
#  'C07648',
#  'C07649',
#  'C08276',
#  'C08325',
#  'C08334',
#  'C08353',
#  'C09804',
#  'C09811',
#  'C09812',
#  'C09813',
#  'C09815',
#  'C09817',
#  'C09818',
#  'C09819',
#  'C09820',
#  'C09822',
#  'C09823',
#  'C09848',
#  'C09849',
#  'C10682',
#  'C11038',
#  'C11039',
#  'C11062',
#  'C11142',
#  'C11143',
#  'C11145',
#  'C11150',
#  'C11355',
#  'C11384',
#  'C11386',
#  'C11434',
#  'C11435',
#  'C11436',
#  'C11437',
#  'C11453',
#  'C11499',
#  'C11536',
#  'C11537',
#  'C11538',
#  'C11542',
#  'C11545',
#  'C11736',
#  'C11811',
#  'C11829',
#  'C11830',
#  'C11831',
#  'C11838',
#  'C11903',
#  'C11904',
#  'C11907',
#  'C11908',
#  ...]

# %%
# Save downloaded data
import csv
with open('curated_met_ids.csv', 'w') as outfile:
    wr = csv.writer(outfile)
    wr.writerow(curated_metabolites)
    outfile.close()
    
with open('missing_metnames.csv', 'w') as outfile:
    wr = csv.writer(outfile)
    wr.writerow(missing_metnames)
    outfile.close()

with open ('metnames.csv', 'w') as outfile:
    wr = csv.writer(outfile)
    wr.writerow(metnames)
    outfile.close()

# %%
name_smiles = dict()

for metabolite in metnames:
    for name in metabolite:
        if get_smiles(name):
            break
# Out:
# SMILES for Water: O
# SMILES for Adenosine 5'-triphosphate: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)N
# SMILES for beta-NAD+: C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)([O-])OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O)C(=O)N
# SMILES for Reduced nicotinamide adenine dinucleotide: C1C=CN(C=C1C(=O)N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O
# SMILES for Reduced nicotinamide adenine dinucleotide phosphate: C1C=CN(C=C1C(=O)N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)OP(=O)(O)O)O)O)O
# SMILES for beta-NADP+: C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)OP(=O)(O)O)O)O)O)C(=O)N
# SMILES for O2: O=O
# SMILES for Adenosine 5'-diphosphate: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O)N
# SMILES for Orthophosphoric acid: OP(=O)(O)O
# SMILES for CoA-SH: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCS)O
# SMILES for Carbon dioxide: C(=O)=O
# SMILES for NH3: N
# SMILES for Uridine 5'-diphosphate: C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)O)O)O
# SMILES for Flavin adenine dinucleotide: CC1=CC2=C(C=C1C)N(C3=NC(=O)NC(=O)C3=N2)CC(C(C(COP(=O)(O)OP(=O)(O)OCC4C(C(C(O4)N5C=NC6=C(N=CN=C65)N)O)O)O)O)O
# SMILES for PLP: CC1=NC=C(C(=C1O)C=O)COP(=O)(O)O
# SMILES for SAM: C[S+](CCC(C(=O)[O-])N)CC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)O
# SMILES for Adenosine 5'-phosphate: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)O)O)N
# SMILES for S-Adenosylhomocysteine: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)CSCCC(C(=O)O)N)O)O)N
# SMILES for Pyroracemic acid: CC(=O)C(=O)O
# SMILES for Acetyl coenzyme A: CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for Glutamate: C(CC(=O)O)C(C(=O)O)N
# SMILES for alpha-Ketoglutaric acid: C(CC(=O)O)C(=O)C(=O)O
# SMILES for Oxydol: OO
# SMILES for UDP-alpha-D-glucose: C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(C(O3)CO)O)O)O)O)O
# SMILES for D-Glucopyranose: C(C1C(C(C(C(O1)O)O)O)O)O
# SMILES for Protoheme IX: CC1=C(C2=CC3=C(C(=C([N-]3)C=C4C(=C(C(=N4)C=C5C(=C(C(=N5)C=C1[N-]2)C)C=C)C)C=C)C)CCC(=O)O)CCC(=O)O.[Fe+2]
# SMILES for Ethanoic acid: CC(=O)O
# SMILES for Guanosine diphosphate: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O)N=C(NC2=O)N
# SMILES for keto-Oxaloacetate: C(C(=O)C(=O)O)C(=O)O
# SMILES for Glycine;: C(C(=O)O)N
# SMILES for L-alpha-Alanine: CC(C(=O)O)N
# SMILES for Ethylenesuccinic acid: C(CC(=O)O)C(=O)O
# SMILES for UDP-N-acetylglucosamine: CC(=O)NC1C(C(C(OC1OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)CO)O)O
# SMILES for Guanosine 5'-triphosphate: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)N=C(NC2=O)N
# SMILES for 2,6-Diaminohexanoic acid: C(CCN)CC(C(=O)O)N
# SMILES for Glyoxylic acid: C(=O)C(=O)O
# SMILES for L-Asp: C(C(C(=O)O)N)C(=O)O
# SMILES for Glutathione;: C(CC(=O)NC(CS)C(=O)NCC(=O)O)C(C(=O)O)N
# SMILES for UDP-alpha-D-galactopyranose: C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(C(O3)CO)O)O)O)O)O
# SMILES for PAPS: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OS(=O)(=O)O)OP(=O)(O)O)O)N
# SMILES for Phosphoadenosine phosphate: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)OP(=O)(O)O)O)N
# SMILES for Cytidylic acid: C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)O)O)O
# SMILES for Formic acid: C(=O)O
# SMILES for Sulfuric acid: OS(=O)(=O)O
# SMILES for Flavin mononucleotide: CC1=CC2=C(C=C1C)N(C3=NC(=O)NC(=O)C3=N2)CC(C(C(COP(=O)(O)O)O)O)O
# SMILES for L-Arg: C(CC(C(=O)O)N)CN=C(N)N
# SMILES for Cytidine triphosphate: C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O
# SMILES for L-2-Aminoglutaramic acid: C(CC(=O)N)C(C(=O)O)N
# SMILES for L-Serine;: C(C(C(=O)O)N)O
# SMILES for Formalin: C=O
# SMILES for ThPP: CC1=C(SC=[N+]1CC2=CN=C(N=C2N)C)CCOP(=O)(O)OP(=O)(O)O
# SMILES for Vitamin C: C(C(C1C(=C(C(=O)O1)O)O)O)O
# SMILES for L-Methionine;: CSCCC(C(=O)O)N
# SMILES for PEP: C=C(C(=O)O)OP(=O)(O)O
# SMILES for Uridine triphosphate: C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O
# SMILES for (S)-2,5-Diaminopentanoate: C(CC(C(=O)O)N)CN
# SMILES for (S)-alpha-Amino-beta-(3-indolyl)-propionic acid: C1=CC=C2C(=C1)C(=CN2)CC(C(=O)O)N
# SMILES for (S)-alpha-Amino-beta-phenylpropionic acid: C1=CC=C(C=C1)CC(C(=O)O)N
# SMILES for Hydron: [H+]
# SMILES for Inosine tripolyphosphate: C1=NC2=C(C(=O)N1)N=CN2C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O
# SMILES for Tyrosine: C1=CC(=CC=C1CC(C(=O)O)N)O
# SMILES for Malonyl coenzyme A: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CC(=O)O)O
# SMILES for Ethanal: CC=O
# SMILES for Neuberg ester: C(C1C(C(C(O1)(CO)O)O)O)OP(=O)(O)O
# SMILES for Carbamide: C(=O)(N)N
# SMILES for Nitrite: N(=O)[O-]
# SMILES for 1-alpha-D-Glucopyranosyl-2-beta-D-fructofuranoside: C(C1C(C(C(C(O1)OC2(C(C(C(O2)CO)O)O)CO)O)O)O)O
# SMILES for Succinyl coenzyme A: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CCC(=O)O)O
# SMILES for Robison ester: C(C1C(C(C(C(O1)O)O)O)O)OP(=O)(O)O
# SMILES for D-Glycerol 1-phosphate: C(C(COP(=O)(O)O)O)O
# SMILES for Sulfurous acid: OS(=O)O
# SMILES for D-arabino-Hexulose: C(C1C(C(C(O1)(CO)O)O)O)O
# SMILES for GDP-alpha-D-mannose: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OC4C(C(C(C(O4)CO)O)O)O)O)O)N=C(NC2=O)N
# SMILES for L-2-Amino-3-mercaptopropionic acid: C(C(C(=O)O)N)S
# SMILES for beta-Alanine;: C(CN)C(=O)O
# SMILES for Propionyl coenzyme A: CCC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for (6S)-THFA: C1C(NC2=C(N1)N=C(NC2=O)N)CNC3=CC=C(C=C3)C(=O)NC(CCC(=O)O)C(=O)O
# SMILES for D-Glucose alpha-1-phosphate: C(C1C(C(C(C(O1)OP(=O)(O)O)O)O)O)O
# SMILES for Inosine diphosphate: C1=NC2=C(C(=O)N1)N=CN2C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O
# SMILES for Uridylate: C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)O)O)O
# SMILES for Uracil: C1=CNC(=O)NC1=O
# SMILES for 2-Aminobenzoate: C1=CC=C(C(=C1)C(=O)[O-])N
# SMILES for alpha-Ketobutyrate: CCC(=O)C(=O)[O-]
# SMILES for 3-Hydroxy-2-oxopropyl phosphate: C(C(=O)COP(=O)(O)O)O
# SMILES for Cytidine diphosphate: C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)O)O)O
# SMILES for Bilineurine: C[N+](C)(C)CCO
# SMILES for 1,2,3-Propanetriol: C(C(CO)O)O
# SMILES for Ribose 5-phosphate: C(C(C(C(C=O)O)O)O)OP(=O)(O)O
# SMILES for Glyceraldehyde 3-phosphate: C(C(C=O)O)OP(=O)(O)O
# SMILES for PRPP: C(C1C(C(C(O1)OP(=O)(O)OP(=O)(O)O)O)O)OP(=O)(O)O
# SMILES for Coenzyme R: C1C2C(C(S1)CCCCC(=O)O)NC(=O)N2
# SMILES for D-Ribose: C1C(C(C(C(O1)O)O)O)O
# SMILES for trans-Butenedioic acid: C(=CC(=O)O)C(=O)O
# SMILES for L-Leucine;: CC(C)CC(C(=O)O)N
# SMILES for D-Galactopyranose: C(C1C(C(C(C(O1)O)O)O)O)O
# SMILES for Oxidized glutathione: C(CC(=O)NC(CSSCC(C(=O)NCC(=O)O)NC(=O)CCC(C(=O)O)N)C(=O)NCC(=O)O)C(C(=O)O)N
# SMILES for 3-Methylbut-3-en-1-yl diphosphate: CC(=C)CCOP(=O)([O-])OP(=O)([O-])[O-]
# SMILES for 5'-IMP: C1=NC2=C(C(=O)N1)N=CN2C3C(C(C(O3)COP(=O)(O)O)O)O
# SMILES for Deoxyadenosine triphosphate: C1C(C(OC1N2C=NC3=C(N=CN=C32)N)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O
# SMILES for CH3OH: CO
# SMILES for D-Ala: CC(C(=O)O)N
# SMILES for Butane-1,4-diamine: C(CCN)CN
# SMILES for (S)-alpha-Amino-1H-imidazole-4-propionic acid: C1=C(NC=N1)CC(C(=O)O)N
# SMILES for Butyryl-CoA: CCCC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for Bios I: C1(C(C(C(C(C1O)O)O)O)O)O
# SMILES for GlcNAc: CC(=O)NC1C(C(C(OC1O)CO)O)O
# SMILES for 2-Keto-3-methylbutyric acid: CC(C)C(=O)C(=O)O
# SMILES for 5,10-Methylene-THF: C1C2CN(CN2C3=C(N1)N=C(NC3=O)N)C4=CC=C(C=C4)C(=O)NC(CCC(=O)O)C(=O)O
# SMILES for Guanylic acid: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)O)O)O)N=C(NC2=O)N
# SMILES for 6-Aminopurine: C1=NC2=NC=NC(=C2N1)N
# SMILES for L-Proline;: C1CC(NC1)C(=O)O
# SMILES for Malic acid: C(C(C(=O)O)O)C(=O)O
# SMILES for 2-Aminosuccinamic acid: C(C(C(=O)O)N)C(=O)N
# SMILES for Vitamin PP: C1=CC(=CN=C1)C(=O)N
# SMILES for Hexadecanoyl-CoA: CCCCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for Homocysteine: C(CS)C(C(=O)O)N
# SMILES for Hydroxybenzenecarboxylic acid: C1=CC(=CC=C1C(=O)O)O
# SMILES for 2-Hydroxytricarballylic acid: C(C(=O)O)C(CC(=O)O)(C(=O)O)O
# SMILES for D-Mannopyranose: C(C1C(C(C(C(O1)O)O)O)O)O
# SMILES for Hydroxyacetic acid: C(C(=O)O)O
# SMILES for Propionic acid: CCC(=O)O
# SMILES for Acetoacetic acid: CC(=O)CC(=O)O
# SMILES for 2-Oxo-3-phenylpropanoate: C1=CC=C(C=C1)CC(=O)C(=O)[O-]
# SMILES for UDP-alpha-D-glucuronate: C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(C(O3)C(=O)O)O)O)O)O)O
# SMILES for 3-Hydroxypyruvic acid: C(C(=O)C(=O)O)O
# SMILES for Carbamoyl phosphate: C(=O)(N)OP(=O)(O)O
# SMILES for 5'-Deoxy-5'-(methylsulfanyl)adenosine: CSCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)O
# SMILES for 5-Methyluracil: CC1=CNC(=O)NC1=O
# SMILES for (4-Aminobutyl) guanidine: C(CCN=C(N)N)CN
# SMILES for Dracylic acid: C1=CC=C(C=C1)C(=O)O
# SMILES for Wood sugar: C1C(C(C(C(O1)O)O)O)O
# SMILES for L-Valine;: CC(C)C(C(=O)O)N
# SMILES for 1,3-Dihydroxypropan-2-one: C(C(=O)CO)O
# SMILES for 1-beta-D-Glucopyranosyl-4-D-glucopyranose: C(C1C(C(C(C(O1)OC2C(OC(C(C2O)O)O)CO)O)O)O)O
# SMILES for L-Lactic acid: CC(C(=O)O)O
# SMILES for L-Threonine;: CC(C(C(=O)O)N)O
# SMILES for 2-Hydroxyethylamine: C(CO)N
# SMILES for UDP-alpha-D-xylose: C1C(C(C(C(O1)OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)O)O)O
# SMILES for Glucuronate: C1(C(C(OC(C1O)O)C(=O)O)O)O
# SMILES for Funacomide: CC1=CC2=C(C=C1C)N(C=N2)C3C(C(C(O3)CO)OP(=O)([O-])OC(C)CNC(=O)CCC4(C(C5C6(C(C(C(=N6)C(=C7C(C(C(=N7)C=C8C(C(C(=N8)C(=C4[N-]5)C)CCC(=O)N)(C)C)CCC(=O)N)(C)CC(=O)N)C)CCC(=O)N)(C)CC(=O)N)C)CC(=O)N)C)O.[CH2-]C1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)O.[Co+3]
# SMILES for 2,3-Dihydroxybenzoic acid: C1=CC(=C(C(=C1)O)O)C(=O)O
# SMILES for 3-Phosphoglycerate: C(C(C(=O)O)O)OP(=O)(O)O
# SMILES for Gluconolactone: C(C1C(C(C(C(=O)O1)O)O)O)O
# SMILES for D-Ribulose 5-phosphate: C(C(C(C(=O)CO)O)O)OP(=O)(O)O
# SMILES for UDP-N-acetyl-alpha-D-galactosamine: CC(=O)NC1C(C(C(OC1OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)CO)O)O
# SMILES for 2-Dehydro-3-deoxy-D-gluconic acid: C(C(C(CO)O)O)C(=O)C(=O)O
# SMILES for 2'-Deoxyadenosine 5'-diphosphate: C1C(C(OC1N2C=NC3=C(N=CN=C32)N)COP(=O)(O)OP(=O)(O)O)O
# SMILES for Propan-2-one: CC(=O)C
# SMILES for alpha-D-Glucopyranosyl-(1->4)-D-glucopyranose: C(C1C(C(C(C(O1)OC2C(OC(C(C2O)O)O)CO)O)O)O)O
# SMILES for Ethanedioic acid: C(=O)(C(=O)O)O
# SMILES for Adenosine: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)CO)O)O)N
# SMILES for N-Methylglycine: CNCC(=O)O
# SMILES for Deoxythymidine: CC1=CN(C(=O)NC1=O)C2CC(C(O2)CO)O
# SMILES for D-2-Aminoglutaric acid: C(CC(=O)O)C(C(=O)O)N
# SMILES for beta-D-Glucopyranose: C(C1C(C(C(C(O1)O)O)O)O)O
# SMILES for Malonate semialdehyde: C(C=O)C(=O)O
# SMILES for (E)-4-Coumaroyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C=CC4=CC=C(C=C4)O)O
# SMILES for 5'-Adenylyl sulfate: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OS(=O)(=O)O)O)O)N
# SMILES for Acetyl phosphate: CC(=O)OP(=O)(O)O
# SMILES for D-Xylulose 5-phosphate: C(C(C(C(=O)CO)O)O)OP(=O)(O)O
# SMILES for 4-Oxobutanoate: C(CC(=O)[O-])C=O
# SMILES for 2-Oxoisocaproate: CC(C)CC(=O)C(=O)O
# SMILES for 10-Formyl-THF: C1C(NC2=C(N1)N=C(NC2=O)N)CN(C=O)C3=CC=C(C=C3)C(=O)NC(CCC(=O)O)C(=O)O
# SMILES for Prenyl diphosphate: CC(=CCOP(=O)(O)OP(=O)(O)O)C
# SMILES for D-Glycerate 1,3-diphosphate: C(C(C(=O)OP(=O)(O)O)O)OP(=O)(O)O
# SMILES for Carbon monoxide: [C-]#[O+]
# SMILES for 2'-Deoxycytidine 5'-monophosphate: C1C(C(OC1N2C=CC(=NC2=O)N)COP(=O)(O)O)O
# SMILES for 2-Amino-6-hydroxypurine: C1=NC2=C(N1)C(=O)NC(=N2)N
# SMILES for Nitric acid: [N+](=O)(O)[O-]
# SMILES for Aminoethylsulfonic acid: C(CS(=O)(=O)O)N
# SMILES for Butyric acid: CCCC(=O)O
# SMILES for Thioctic acid amide: C1CSSC1CCCCC(=O)N
# SMILES for Cetylic acid: CCCCCCCCCCCCCCCC(=O)O
# SMILES for Pyridoxal: CC1=NC=C(C(=C1O)C=O)CO
# SMILES for (3R,4R)-3-[(1-Carboxyethenyl)oxy]-4-hydroxycyclohexa-1,5-diene-1-carboxylate: C=C(C(=O)O)OC1C=C(C=CC1O)C(=O)O
# SMILES for Brachiose: C(C1C(C(C(C(O1)OCC2C(C(C(C(O2)O)O)O)O)O)O)O)O
# SMILES for 3-Pyridinecarboxylic acid: C1=CC(=CN=C1)C(=O)O
# SMILES for Prephenic acid: C1=CC(C=CC1O)(CC(=O)C(=O)O)C(=O)O
# SMILES for Vitamin B2: CC1=CC2=C(C=C1C)N(C3=NC(=O)NC(=O)C3=N2)CC(C(C(CO)O)O)O
# SMILES for D-2-Hydroxypropionic acid: CC(C(=O)O)O
# SMILES for D-gluco-Hexonic acid: C(C(C(C(C(C(=O)O)O)O)O)O)O
# SMILES for Glyceric acid: C(C(C(=O)O)O)O
# SMILES for Benzoic aldehyde: C1=CC=C(C=C1)C=O
# SMILES for Purine-6-ol: C1=NC2=C(N1)C(=O)NC=N2
# SMILES for 2-Amino-4-hydroxybutyric acid: C(CO)C(C(=O)O)N
# SMILES for Hydroxyacetaldehyde: C(C=O)O
# SMILES for alpha-D-Glucose: C(C1C(C(C(C(O1)O)O)O)O)O
# SMILES for L-erythro-Tetrahydrobiopterin: CC(C(C1CNC2=C(N1)C(=O)NC(=N2)N)O)O
# SMILES for D-Mannose 6-phosphate: C(C1C(C(C(C(O1)O)O)O)O)OP(=O)(O)O
# SMILES for D-Erythrose 4-phosphate: C(C(C(C=O)O)O)OP(=O)(O)O
# SMILES for 4-Androstene-3,17-dione: CC12CCC(=O)C=C1CCC3C2CCC4(C3CCC4=O)C
# SMILES for H2: [HH]
# SMILES for Sulfide: [S-2]
# SMILES for Deoxyguanosine triphosphate: C1C(C(OC1N2C=NC3=C2N=C(NC3=O)N)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O
# SMILES for Acid carbonate: C(=O)(O)[O-]
# SMILES for Inosine: C1=NC2=C(C(=O)N1)N=CN2C3C(C(C(O3)CO)O)O
# SMILES for Uracil-6-carboxylic acid: C1=C(NC(=O)NC1=O)C(=O)O
# SMILES for Uridine: C1=CN(C(=O)NC1=O)C2C(C(C(O2)CO)O)O
# SMILES for Adenosine diphosphate ribose: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OCC4C(C(C(O4)O)O)O)O)O)N
# SMILES for 2-Aminoglutaric acid: C(CC(=O)O)C(C(=O)O)N
# SMILES for D-Lyxulose: C1C(C(C(O1)(CO)O)O)O
# SMILES for 1-Hydroxypropane-1,2,3-tricarboxylic acid: C(C(C(C(=O)O)O)C(=O)O)C(=O)O
# SMILES for L-Lyxulose: C1C(C(C(O1)(CO)O)O)O
# SMILES for Oxalyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C(=O)O)O
# SMILES for Pyridoxol: CC1=NC=C(C(=C1O)CO)CO
# SMILES for N-(3-Aminopropyl)-1,4-butane-diamine: C(CCNCCCN)CN
# SMILES for (R)-Carnitine: C[N+](C)(C)CC(CC(=O)[O-])O
# SMILES for 2-Oxohexanedioic acid: C(CC(=O)C(=O)O)CC(=O)O
# SMILES for (2E)-3-(3,4-Dihydroxyphenyl)prop-2-enoyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C=CC4=CC(=C(C=C4)O)O)O
# SMILES for Citrulline: C(CC(C(=O)O)N)CNC(=O)N
# SMILES for 2'-Deoxyguanosine: C1C(C(OC1N2C=NC3=C2N=C(NC3=O)N)CO)O
# SMILES for 3-(Indol-3-yl)pyruvate: C1=CC=C2C(=C1)C(=CN2)CC(=O)C(=O)[O-]
# SMILES for 3-Acetoacetyl-CoA: CC(=O)CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for GABA: C(CC(=O)O)CN
# SMILES for Dihydro-L-orotic acid: C1C(NC(=O)NC1=O)C(=O)O
# SMILES for Geranyl diphosphate: CC(=CCCC(=CCOP(=O)(O)OP(=O)(O)O)C)C
# SMILES for 6-Phospho-D-gluconate: C(C(C(C(C(C(=O)O)O)O)O)O)OP(=O)(O)O
# SMILES for Methylmalonate semialdehyde: CC(C=O)C(=O)O
# SMILES for D-Glucosamine phosphate: C(C1C(C(C(C(O1)O)N)O)O)OP(=O)(O)O
# SMILES for (2E,6E,10E)-3,7,11,15-Tetramethylhexadeca-2,6,10,14-tetraen-1-yl diphosphate: CC(=CCCC(=CCCC(=CCCC(=CCOP(=O)([O-])OP(=O)([O-])[O-])C)C)C)C
# SMILES for 3-Hydroxy-3-methylglutaryl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CC(C)(CC(=O)O)O)O
# SMILES for N-Acetyl-D-glucosamine 6-phosphate: CC(=O)NC1C(C(C(OC1O)COP(=O)(O)O)O)O
# SMILES for Deoxyadenosine monophosphate: C1C(C(OC1N2C=NC3=C(N=CN=C32)N)COP(=O)(O)O)O
# SMILES for 2'-Deoxyguanosine 5'-diphosphate: C1C(C(OC1N2C=NC3=C2N=C(NC3=O)N)COP(=O)(O)OP(=O)(O)O)O
# SMILES for Deoxyguanosine monophosphate: C1C(C(OC1N2C=NC3=C2N=C(NC3=O)N)COP(=O)(O)O)O
# SMILES for Deoxythymidine 5'-diphosphate: CC1=CN(C(=O)NC1=O)C2CC(C(O2)COP(=O)(O)OP(=O)(O)O)O
# SMILES for Thymidylate: CC1=CN(C(=O)NC1=O)C2CC(C(O2)COP(=O)(O)O)O
# SMILES for 2'-Deoxyuridine 5'-phosphate: C1C(C(OC1N2C=CC(=O)NC2=O)COP(=O)(O)O)O
# SMILES for Uric acid: C12=C(NC(=O)N1)NC(=O)NC2=O
# SMILES for all-trans-Retinene: CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CC=O)C)C
# SMILES for Antiberiberi factor: CC1=C(SC=[N+]1CC2=CN=C(N=C2N)C)CCO
# SMILES for Cytosine: C1=C(NC(=O)N=C1)N
# SMILES for Xanthine: C1=NC2=C(N1)C(=O)NC(=O)N2
# SMILES for Guanosine: C1=NC2=C(N1C3C(C(C(O3)CO)O)O)N=C(NC2=O)N
# SMILES for D-Aspartic acid: C(C(C(=O)O)N)C(=O)O
# SMILES for (E)-3-(4-Hydroxy-3-methoxyphenyl)propenoyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C=CC4=CC(=C(C=C4)O)OC)O
# SMILES for 2-Amino-3-methylvaleric acid: CCC(C)C(C(=O)O)N
# SMILES for Methylmercaptan: CS
# SMILES for Sinapoyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C=CC4=CC(=C(C(=C4)OC)O)OC)O
# SMILES for Cyclohexanone: C1CCC(=O)CC1
# SMILES for 7,8-Dihydropteroylglutamate: C1C(=NC2=C(N1)N=C(NC2=O)N)CNC3=CC=C(C=C3)C(=O)NC(CCC(=O)O)C(=O)O
# SMILES for cis-Aconitic acid: C(C(=CC(=O)O)C(=O)O)C(=O)O
# SMILES for (2E)-3-Phenylprop-2-enoate: C1=CC=C(C=C1)C=CC(=O)[O-]
# SMILES for L-2-Hydroxypropionaldehyde: CC(C=O)O
# SMILES for 5-Amino-4-oxopentanoic acid: C(CC(=O)O)C(=O)CN
# SMILES for 5-Aminovaleric acid: C(CCN)CC(=O)O
# SMILES for 2-Oxoglutarate semialdehyde: C(CC(=O)C(=O)O)C=O
# SMILES for N-Carbamoylputrescine: C(CCNC(=O)N)CN
# SMILES for N2-Acetyl-L-ornithine: CC(=O)NC(CCCN)C(=O)O
# SMILES for N-Carbamoyl-L-aspartate: C(C(C(=O)O)NC(=O)N)C(=O)O
# SMILES for 5-Methyltetrahydrofolate: CN1C(CNC2=C1C(=O)NC(=N2)N)CNC3=CC=C(C=C3)C(=O)NC(CCC(=O)O)C(=O)O
# SMILES for L-Aspartic 4-semialdehyde: C(C=O)C(C(=O)O)N
# SMILES for 5,10-Methenyltetrahydrofolate: C1C2CN(C=[N+]2C3=C(N1)N=C(NC3=O)N)C4=CC=C(C=C4)C(=O)NC(CCC(=O)O)C(=O)O
# SMILES for alpha-D-Galactopyranose 1-phosphate: C(C1C(C(C(C(O1)OP(=O)(O)O)O)O)O)O
# SMILES for D-altro-Heptulose 1,7-biphosphate: C(C(C(C(C(C(=O)COP(=O)(O)O)O)O)O)O)OP(=O)(O)O
# SMILES for (2E,6E)-Farnesyl diphosphate: CC(=CCCC(=CCCC(=CCOP(=O)(O)OP(=O)(O)O)C)C)C
# SMILES for beta-Nicotinamide mononucleotide: C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)(O)[O-])O)O)C(=O)N
# SMILES for 2'-Deoxycytidine 5'-triphosphate: C1C(C(OC1N2C=CC(=NC2=O)N)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O
# SMILES for TTP: CC1=CN(C(=O)NC1=O)C2CC(C(O2)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O
# SMILES for 2'-Deoxyuridine 5'-triphosphate: C1C(C(OC1N2C=CC(=O)NC2=O)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O
# SMILES for 2,3-Benzopyrrole: C1=CC=C2C(=C1)C=CN2
# SMILES for 3-Hydroxy-1,3,5(10)-estratrien-17-one: CC12CCC3C(C1CCC2=O)CCC4=C3C=CC(=C4)O
# SMILES for Methylcarbinol: CCO
# SMILES for Vitamin A1: CC1=C(C(CCC1)(C)C)C=CC(=CC=CC(=CCO)C)C
# SMILES for Cytidine: C1=CN(C(=O)N=C1N)C2C(C(C(O2)CO)O)O
# SMILES for Propionaldehyde: CCC=O
# SMILES for 3,5-Dimethoxy-4-hydroxycinnamic acid: COC1=CC(=CC(=C1O)OC)C=CC(=O)O
# SMILES for Bilirubin: CC1=C(NC(=C1CCC(=O)O)CC2=C(C(=C(N2)C=C3C(=C(C(=O)N3)C)C=C)C)CCC(=O)O)C=C4C(=C(C(=O)N4)C=C)C
# SMILES for 1,3-Propanedicarboxylic acid: C(CC(=O)O)CC(=O)O
# SMILES for Methylenesuccinic acid: C=C(CC(=O)O)C(=O)O
# SMILES for L-alpha-Diamino-beta-dithiolactic acid: C(C(C(=O)O)N)SSCC(C(=O)O)N
# SMILES for 6G-alpha-D-galactosylsucrose: C(C1C(C(C(C(O1)OCC2C(C(C(C(O2)OC3(C(C(C(O3)CO)O)O)CO)O)O)O)O)O)O)O
# SMILES for 3,4,5-Trihydroxy-1-cyclohexenecarboxylic acid: C1C(C(C(C=C1C(=O)O)O)O)O
# SMILES for D-Malic acid: C(C(C(=O)O)O)C(=O)O
# SMILES for Adenosine diphosphoglucose: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OC4C(C(C(C(O4)CO)O)O)O)O)O)N
# SMILES for Allantoic acid: C(C(=O)O)(NC(=O)N)NC(=O)N
# SMILES for Biliverdin IX alpha: CC1=C(C(=CC2=C(C(=C(N2)C=C3C(=C(C(=O)N3)C)C=C)C)CCC(=O)O)NC1=CC4=NC(=O)C(=C4C)C=C)CCC(=O)O
# SMILES for D-Xylonate: C(C(C(C(C(=O)[O-])O)O)O)O
# SMILES for Erythrite: C(C(C(CO)O)O)O
# SMILES for Folic acid: C1=CC(=CC=C1C(=O)NC(CCC(=O)O)C(=O)O)NCC2=CN=C3C(=N2)C(=O)NC(=N3)N
# SMILES for 2-Amino-3-sulfopropionic acid: C(C(C(=O)O)N)S(=O)(=O)O
# SMILES for L-Rhamnopyranose: CC1C(C(C(C(O1)O)O)O)O
# SMILES for Vinylformic acid: C=CC(=O)O
# SMILES for S-Benzoyl-coenzyme A: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C4=CC=CC=C4)O
# SMILES for Pantoic acid: CC(C)(CO)C(C(=O)O)O
# SMILES for 2'-Deoxyuridine: C1C(C(OC1N2C=CC(=O)NC2=O)CO)O
# SMILES for Glutaryl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CCCC(=O)O)O
# SMILES for Itaconyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CC(=C)C(=O)O)O
# SMILES for Nitrogen monoxide: [N]=O
# SMILES for 17beta-Hydroxy-4-androsten-3-one: CC12CCC3C(C1CCC2O)CCC4=CC(=O)CCC34C
# SMILES for Inorganic triphosphate: OP(=O)(O)OP(=O)(O)OP(=O)(O)O
# SMILES for S-(Cinnamoyl) coenzyme A: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C=CC4=CC=CC=C4)O
# SMILES for Cystathionine: C(CSCC(C(=O)O)N)C(C(=O)O)N
# SMILES for 2-Oxopropanal: CC(=O)C=O
# SMILES for meso-Tartrate: C(C(C(=O)[O-])O)(C(=O)[O-])O
# SMILES for 4-Aminobutanal: C(CC=O)CN
# SMILES for 2'-Deoxyadenosine: C1C(C(OC1N2C=NC3=C(N=CN=C32)N)CO)O
# SMILES for (R)-Mandelonitrile: C1=CC=C(C=C1)C(C#N)O
# SMILES for p-Aminobenzoate: C1=CC(=CC=C1C(=O)[O-])N
# SMILES for Betaine aldehyde: C[N+](C)(C)CC=O
# SMILES for D-Glyceraldehyde: C(C(C=O)O)O
# SMILES for Dihydrothioctamide: C(CCC(=O)N)CC(CCS)S
# SMILES for Methyl thioether: CSC
# SMILES for Propylene glycol: CC(CO)O
# SMILES for m-Hydroxybenzoic acid: C1=CC(=CC(=C1)O)C(=O)O
# SMILES for 2-Oxoethanesulfonate: C(C=O)S(=O)(=O)[O-]
# SMILES for alpha-Tolualdehyde: C1=CC=C(C=C1)CC=O
# SMILES for (-)-Ureidoglycolate: C(C(=O)O)(NC(=O)N)O
# SMILES for 3-Sulfinoalanine: C(C(C(=O)O)N)S(=O)O
# SMILES for UDP-alpha-D-galacturonate: C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)([O-])OP(=O)([O-])OC3C(C(C(C(O3)C(=O)[O-])O)O)O)O)O
# SMILES for 3-Dehydro-L-gulonate: C(C(C(C(=O)C(C(=O)O)O)O)O)O
# SMILES for D-Ribose 1-phosphate: C(C1C(C(C(O1)OP(=O)(O)O)O)O)O
# SMILES for L-Glycerol 1-phosphate: C(C(COP(=O)(O)O)O)O
# SMILES for N-Acetyl-L-glutamic acid: CC(=O)NC(CCC(=O)O)C(=O)O
# SMILES for 2-Phospho-(R)-glycerate: C(C(C(=O)O)OP(=O)(O)O)O
# SMILES for p-Hydroxybenzaldehyde: C1=CC(=CC=C1C=O)O
# SMILES for alpha-D-Mannose 1-phosphate: C(C1C(C(C(C(O1)OP(=O)(O)O)O)O)O)O
# SMILES for Indoleacetaldehyde: C1=CC=C2C(=C1)C(=CN2)CC=O
# SMILES for 4-Hydroxyphenylacetic acid: C1=CC(=CC=C1CC(=O)O)O
# SMILES for 2-Acetamido-2-deoxy-D-mannose: CC(=O)NC1C(C(C(OC1O)CO)O)O
# SMILES for (9-D-Ribosylxanthine)-5'-phosphate: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)O)O)O)NC(=O)NC2=O
# SMILES for (2S,6S)-2,6-Diaminoheptanedioic acid: C(CC(C(=O)O)N)CC(C(=O)O)N
# SMILES for Glycerophosphocholine: C[N+](C)(C)CCOP(=O)([O-])OCC(CO)O
# SMILES for (3S)-3-Methyl-2-oxopentanoate: CCC(C)C(=O)C(=O)[O-]
# SMILES for 2-Deoxy-alpha-D-ribose 1-phosphate: C1C(C(OC1OP(=O)(O)O)CO)O
# SMILES for Androstanedione: CC12CCC(=O)CC1CCC3C2CCC4(C3CCC4=O)C
# SMILES for (2R,3S)-2,3-Dihydroxy-5-oxohexanedioate: C(C(C(C(=O)[O-])O)O)C(=O)C(=O)[O-]
# SMILES for meso-Diaminoheptanedioate: C(CC(C(=O)O)N)CC(C(=O)O)N
# SMILES for 2-Hydroxymuconate-6-semialdehyde: C(=CC(=O)C(=O)O)C=CO
# SMILES for D-Methylmalonyl-CoA: CC(C(=O)O)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for dTDP-4-oxo-L-rhamnose: CC1C(=O)C(C(C(O1)OP(=O)(O)OP(=O)(O)OCC2C(CC(O2)N3C=C(C(=O)NC3=O)C)O)O)O
# SMILES for Trehalose 6-phosphate: C(C1C(C(C(C(O1)OC2C(C(C(C(O2)COP(=O)(O)O)O)O)O)O)O)O)O
# SMILES for 2-Inosose: C1(C(C(C(=O)C(C1O)O)O)O)O
# SMILES for UDP-N-acetyl-alpha-D-muramoyl-L-alanyl-D-glutamate: CC(C(=O)NC(CCC(=O)[O-])C(=O)[O-])NC(=O)C(C)OC1C(C(OC(C1O)CO)OP(=O)([O-])OP(=O)([O-])OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)NC(=O)C
# SMILES for Xanthosine 5'-triphosphate: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)NC(=O)NC2=O
# SMILES for 2'-Deoxycytidine 5'-diphosphate: C1C(C(OC1N2C=CC(=NC2=O)N)COP(=O)(O)OP(=O)(O)O)O
# SMILES for Trimethylammonioacetate: C[N+](C)(C)CC(=O)[O-]
# SMILES for 3alpha-Tropanol: CN1C2CCC1CC(C2)O
# SMILES for D-Serine: C(C(C(=O)O)N)O
# SMILES for 2,3-Butanedione: CC(=O)C(=O)C
# SMILES for Siroheme: CC1(C(C2=CC3=NC(=CC4=C(C(=C([N-]4)C=C5C(C(C(=N5)C=C1[N-]2)CCC(=O)O)(C)CC(=O)O)CC(=O)O)CCC(=O)O)C(=C3CC(=O)O)CCC(=O)O)CCC(=O)O)CC(=O)O.[Fe+2]
# SMILES for N,N'-Bis(3-aminopropyl)-1,4-butanediamine: C(CCNCCCN)CNCCCN
# SMILES for 4-Hydroxy-3-methoxybenzaldehyde: COC1=C(C=CC(=C1)C=O)O
# SMILES for 3-Tropanone: CN1C2CCC1CC(=O)C2
# SMILES for Urocanic acid: C1=C(NC=N1)C=CC(=O)O
# SMILES for CDP 5-ester with D-ribitol: C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC(C(C(CO)O)O)O)O)O
# SMILES for lyxo-Hexulose: C1C(C(C(C(O1)(CO)O)O)O)O
# SMILES for Gulonic acid: C(C(C(C(C(C(=O)O)O)O)O)O)O
# SMILES for N-Carbamoyl-2-oxoglycine: C(=O)(C(=O)[O-])NC(=O)N
# SMILES for Acetylenemonocarboxylate: C#CC(=O)O
# SMILES for (3R)-3-Hydroxybutan-2-one: CC(C(=O)C)O
# SMILES for 4-Hydroxycinnamate: C1=CC(=CC=C1C=CC(=O)O)O
# SMILES for Glucarate: C(C(C(C(=O)[O-])O)O)(C(C(=O)[O-])O)O
# SMILES for D-2-Aminoglutaramic acid: C(CC(=O)N)C(C(=O)O)N
# SMILES for Pretyrosine: C1=CC(C=CC1O)(CC(C(=O)O)N)C(=O)O
# SMILES for Vitamin K2: CC1=C(C(=O)C2=CC=CC=C2C1=O)CC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C
# SMILES for (R)-Pantetheine: CC(C)(CO)C(C(=O)NCCC(=O)NCCS)O
# SMILES for dTDP-alpha-D-glucose: CC1=CN(C(=O)NC1=O)C2CC(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(C(O3)CO)O)O)O)O
# SMILES for (R)-Prunasin: C1=CC=C(C=C1)C(C#N)OC2C(C(C(C(O2)CO)O)O)O
# SMILES for 2-Furoyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C4=CC=CO4)O
# SMILES for 3-Oxohexanedioic acid: C(CC(=O)O)C(=O)CC(=O)O
# SMILES for Vitamin B12s: CC1=CC2=C(C=C1C)N(C=N2)C3C(C(C(O3)CO)OP(=O)(O)OC(C)CNC(=O)CCC4(C(C5C6(C(C(C(=N6)C(=C7C(C(C(=N7)C=C8C(C(C(=N8)C(=C4[N-]5)C)CCC(=O)N)(C)C)CCC(=O)N)(C)CC(=O)N)C)CCC(=O)N)(C)CC(=O)N)C)CC(=O)N)C)O.[Co]
# SMILES for Cyclohexan-1-ol: C1CCC(CC1)O
# SMILES for Nicotinic acid adenine dinucleotide: C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O)C(=O)O
# SMILES for L-Histidinol: C1=C(NC=N1)CC(CO)N
# SMILES for (R)-Pantothenate: CC(C)(CO)C(C(=O)NCCC(=O)O)O
# SMILES for 4-Hydroxynitrobenzene: C1=CC(=CC=C1[N+](=O)[O-])O
# SMILES for Coenzyme gamma-F420-2: CC(C(=O)NC(CCC(=O)NC(CCC(=O)O)C(=O)O)C(=O)O)OP(=O)(O)OCC(C(C(CN1C2=CC(=O)C=CC2=CC3=C1NC(=O)NC3=O)O)O)O
# SMILES for (2E)-But-2-enoyl-CoA: CC=CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for 2'-Deoxycytidine: C1C(C(OC1N2C=CC(=NC2=O)N)CO)O
# SMILES for 3'-Dephospho-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)O)C(C(=O)NCCC(=O)NCCS)O
# SMILES for Isochorismic acid: C=C(C(=O)O)OC1C=CC=C(C1O)C(=O)O
# SMILES for Acrylyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C=C)O
# SMILES for (+)-Tartaric acid: C(C(C(=O)O)O)(C(=O)O)O
# SMILES for 2-Hydroxy-2-methyl-3-oxobutanoic acid: CC(=O)C(C)(C(=O)O)O
# SMILES for 7,8-Dihydropteroate: C1C(=NC2=C(N1)N=C(NC2=O)N)CNC3=CC=C(C=C3)C(=O)O
# SMILES for Porphobilinogen: C1=C(C(=C(N1)CN)CC(=O)O)CCC(=O)O
# SMILES for UDP-beta-L-arabinopyranose: C1C(C(C(C(O1)OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)O)O)O
# SMILES for D-2-Hydroxypropionaldehyde: CC(C=O)O
# SMILES for 2-Ketoglutaramate: C(CC(=O)N)C(=O)C(=O)O
# SMILES for 5-Dehydroquinic acid: C1C(C(C(=O)CC1(C(=O)O)O)O)O
# SMILES for beta-Estradiol: CC12CCC3C(C1CCC2O)CCC4=C3C=CC(=C4)O
# SMILES for IAA: C1=CC=C2C(=C1)C(=CN2)CC(=O)O
# SMILES for L-2-Aminohexanedioate: C(CC(C(=O)O)N)CC(=O)O
# SMILES for 3-Mercaptopyruvate: C(C(=O)C(=O)O)S
# SMILES for 2-Dehydropantoate: CC(C)(CO)C(=O)C(=O)O
# SMILES for 3-Hydroxypropanal: C(CO)C=O
# SMILES for Cyclodextrin: C(C1C2C(C(C(O1)OC3C(OC(C(C3O)O)OC4C(OC(C(C4O)O)OC5C(OC(C(C5O)O)OC6C(OC(C(C6O)O)OC7C(OC(O2)C(C7O)O)CO)CO)CO)CO)CO)O)O)O
# SMILES for GDP-D-mannuronic acid: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OC4C(C(C(C(O4)C(=O)O)O)O)O)O)O)N=C(NC2=O)N
# SMILES for O3-Acetyl-L-serine: CC(=O)OCC(C(=O)O)N
# SMILES for alpha-D-Galactose: C(C1C(C(C(C(O1)O)O)O)O)O
# SMILES for 4-Hydroxybutyric acid: C(CC(=O)O)CO
# SMILES for 5-Aminopentanamide: C(CCN)CC(=O)N
# SMILES for D-Ala-D-Ala: CC(C(=O)NC(C)C(=O)O)N
# SMILES for 3-Phospho-L-serine: C(C(C(=O)[O-])[NH3+])OP(=O)([O-])[O-]
# SMILES for Reduced riboflavin: CC1=CC2=C(C=C1C)N(C3=C(N2)C(=O)NC(=O)N3)CC(C(C(CO)O)O)O
# SMILES for Allophanic acid: C(=O)(N)NC(=O)O
# SMILES for 6-Hydroxynicotinic acid: C1=CC(=O)NC=C1C(=O)O
# SMILES for Hydroxymethylbilane: C1=C(C(=C(N1)CC2=C(C(=C(N2)CC3=C(C(=C(N3)CC4=C(C(=C(N4)CO)CC(=O)O)CCC(=O)O)CC(=O)O)CCC(=O)O)CC(=O)O)CCC(=O)O)CC(=O)O)CCC(=O)O
# SMILES for 4-Guanidinobutyric acid: C(CC(=O)O)CN=C(N)N
# SMILES for 7,8-Diaminononanoic acid: CC(C(CCCCCC(=O)O)N)N
# SMILES for UDP-MurNAc: CC(C(=O)O)OC1C(C(OC(C1O)CO)OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)NC(=O)C
# SMILES for Uroporphyrinogen III: C1C2=C(C(=C(N2)CC3=C(C(=C(N3)CC4=C(C(=C(N4)CC5=C(C(=C1N5)CCC(=O)O)CC(=O)O)CC(=O)O)CCC(=O)O)CC(=O)O)CCC(=O)O)CC(=O)O)CCC(=O)O
# SMILES for 6-Carboxyhexanoyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CCCCCC(=O)O)O
# SMILES for L-Ribitol 1-phosphate: C(C(C(C(COP(=O)(O)O)O)O)O)O
# SMILES for O-Acetylhomoserine: CC(=O)OCCC(C(=O)O)N
# SMILES for Protoporphyrinogen IX: CC1=C2CC3=C(C(=C(N3)CC4=C(C(=C(N4)CC5=C(C(=C(N5)CC(=C1CCC(=O)O)N2)CCC(=O)O)C)C=C)C)C=C)C
# SMILES for Reduced coenzyme F420: CC(C(=O)NC(CCC(=O)NC(CCC(=O)O)C(=O)O)C(=O)O)OP(=O)(O)OCC(C(C(CN1C2=C(CC3=C1NC(=O)NC3=O)C=CC(=C2)O)O)O)O
# SMILES for Trehalose: C(C1C(C(C(C(O1)OC2C(C(C(C(O2)CO)O)O)O)O)O)O)O
# SMILES for KAPA: CC(C(=O)CCCCCC(=O)O)N
# SMILES for D-Fructose 1-phosphate: C(C(C(C(C(=O)COP(=O)(O)O)O)O)O)O
# SMILES for D-Tagatose 6-phosphate: C(C1C(C(C(O1)(CO)O)O)O)OP(=O)(O)O
# SMILES for L-Histidinol phosphate: C1=C(NC=N1)CC(COP(=O)(O)O)N
# SMILES for O-Phospho-L-homoserine: C(COP(=O)(O)O)C(C(=O)O)N
# SMILES for Orotidylic acid: C1=C(N(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)O)O)O)C(=O)O
# SMILES for 6-Phospho-D-galactose: C(C1C(C(C(C(O1)O)O)O)O)OP(=O)(O)O
# SMILES for O-Succinylhomoserine: C(COC(=O)CCC(=O)O)C(C(=O)O)N
# SMILES for 4-Hydroxy-2-oxoglutaric acid: C(C(C(=O)O)O)C(=O)C(=O)O
# SMILES for D-Pantetheine 4'-phosphate: CC(C)(COP(=O)(O)O)C(C(=O)NCCC(=O)NCCS)O
# SMILES for Decarboxy-AdoMet: C[S+](CCCN)CC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)O
# SMILES for (S)-3-Hydroxybutyryl-CoA: CC(CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O)O
# SMILES for Tartronate semialdehyde: C(=O)C(C(=O)O)O
# SMILES for 4-Trimethylammoniobutanal: C[N+](C)(C)CCCC=O
# SMILES for L-Hydroxyproline;: C1C(CNC1C(=O)O)O
# SMILES for Homoprotocatechuate: C1=CC(=C(C=C1CC(=O)O)O)O
# SMILES for cis,cis-Butadiene-1,2,4-tricarboxylate: C(=CC(=O)O)C(=CC(=O)O)C(=O)O
# SMILES for L-Glutamate gamma-semialdehyde: C(CC(C(=O)O)N)C=O
# SMILES for Pseudouridine 5'-phosphate: C1=C(C(=O)NC(=O)N1)C2C(C(C(O2)COP(=O)(O)O)O)O
# SMILES for UDP-N-acetyl-alpha-D-mannosamine: CC(=O)NC1C(C(C(OC1OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)CO)O)O
# SMILES for 1D-myo-Inositol 1-monophosphate: C1(C(C(C(C(C1O)O)OP(=O)(O)O)O)O)O
# SMILES for p-Hydroxyphenylpyruvic acid: C1=CC(=CC=C1CC(=O)C(=O)O)O
# SMILES for 2-Oxo-4-methylthiobutanoic acid: CSCCC(=O)C(=O)O
# SMILES for gamma-Butyrobetaine: C[N+](C)(C)CCCC(=O)[O-]
# SMILES for Nicotinic acid ribonucleotide: C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)(O)O)O)O)C(=O)O
# SMILES for (2E)-3-(3,4-Dihydroxyphenyl)prop-2-enoate: C1=CC(=C(C=C1C=CC(=O)O)O)[O-]
# SMILES for (R)-3-Aminoisobutyric acid: CC(CN)C(=O)O
# SMILES for UDP-N-acetyl-alpha-D-muramoyl-L-alanine: CC(C(=O)O)NC(=O)C(C)OC1C(C(OC(C1O)CO)OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)NC(=O)C
# SMILES for L-Methylmalonyl-CoA: CC(C(=O)O)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for 2-Dehydro-3-deoxy-D-galactonic acid: C(C(C(CO)O)O)C(=O)C(=O)O
# SMILES for Tetrahydromethanopterin: CC1C(NC2=C(N1)N=C(NC2=O)N)C(C)NC3=CC=C(C=C3)CC(C(C(COC4C(C(C(O4)COP(=O)(O)OC(CCC(=O)O)C(=O)O)O)O)O)O)O
# SMILES for 2-Dehydro-D-gluconate 6-phosphate: C(C(C(C(C(=O)C(=O)O)O)O)O)OP(=O)(O)O
# SMILES for GDP-4-dehydro-6-deoxy-alpha-D-mannose: CC1C(=O)C(C(C(O1)OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=NC4=C3N=C(NC4=O)N)O)O)O)O
# SMILES for DHEA: CC12CCC3C(C1CCC2=O)CC=C4C3(CCC(C4)O)C
# SMILES for Guanosine 5'-diphosphate,3'-diphosphate: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)OP(=O)(O)OP(=O)(O)O)O)N=C(NC2=O)N
# SMILES for all-trans-Hexaprenyl diphosphate: CC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCOP(=O)(O)OP(=O)(O)O)C)C)C)C)C)C
# SMILES for Glycerophosphoethanolamine: C(COP(=O)(O)OCC(CO)O)N
# SMILES for 6-Phospho-D-glucono-1,5-lactone: C(C1C(C(C(C(=O)O1)O)O)O)OP(=O)(O)O
# SMILES for 2-Acetamido-5-oxopentanoate: CC(=O)NC(CCC=O)C(=O)O
# SMILES for (R)-2-Hydroxy-1,2,4-butanetricarboxylic acid: C(CC(CC(=O)O)(C(=O)O)O)C(=O)O
# SMILES for Imidazole-acetol phosphate: C1=C(NC=N1)CC(=O)COP(=O)(O)O
# SMILES for 5-Amino-6-(5-phosphoribosylamino)uracil: C(C1C(C(C(O1)NC2=C(C(=O)NC(=O)N2)N)O)O)OP(=O)(O)O
# SMILES for O5-(1-Carboxyvinyl)-3-phosphoshikimate: C=C(C(=O)O)OC1CC(=CC(C1O)OP(=O)(O)O)C(=O)O
# SMILES for HMP: CC1=NC=C(C(=N1)N)CO
# SMILES for 2-Dehydro-3-deoxy-D-galactonate 6-phosphate: C(C(C(COP(=O)(O)O)O)O)C(=O)C(=O)O
# SMILES for Isohexenyl-glutaconyl-CoA: CC(=CCCC(=CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O)CC(=O)O)C
# SMILES for 2-Amino-4-hydroxy-6-hydroxymethyl-7,8-dihydropteridine: C1C(=NC2=C(N1)N=C(NC2=O)N)CO
# SMILES for 1-(2-Carboxyphenylamino)-1-deoxy-D-ribulose 5-phosphate: C1=CC=C(C(=C1)C(=O)O)NCC(=O)C(C(COP(=O)(O)O)O)O
# SMILES for 2,5-Diamino-6-(1-D-ribosylamino)pyrimidin-4(3H)-one 5'-phosphate: C(C1C(C(C(O1)NC2=C(C(=O)NC(=N2)N)N)O)O)OP(=O)([O-])[O-]
# SMILES for 2'-Deoxyinosine 5'-diphosphate: C1C(C(OC1N2C=NC3=C2N=CNC3=O)COP(=O)(O)OP(=O)(O)O)O
# SMILES for 2'-Deoxyinosine 5'-triphosphate: C1C(C(OC1N2C=NC3=C2N=CNC3=O)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O
# SMILES for 2'-Deoxyuridine 5'-diphosphate: C1C(C(OC1N2C=CC(=O)NC2=O)COP(=O)(O)OP(=O)(O)O)O
# SMILES for FADH2: CC1=CC2=C(C=C1C)N(C3=C(N2)C(=O)NC(=O)N3)CC(C(C(COP(=O)(O)OP(=O)(O)OCC4C(C(C(O4)N5C=NC6=C(N=CN=C65)N)O)O)O)O)O
# SMILES for AMP 3'-phosphate: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)CO)OP(=O)(O)O)O)N
# SMILES for Uridine 3'-phosphate: C1=CN(C(=O)NC1=O)C2C(C(C(O2)CO)OP(=O)(O)O)O
# SMILES for Ethane-1,2-diol: C(CO)O
# SMILES for Butyraldehyde: CCCC=O
# SMILES for L-Cysteinylglycine: C(C(C(=O)NCC(=O)O)N)S
# SMILES for Crithminic acid: CC1=CC=C(C=C1)C(=O)O
# SMILES for 4-Hydroxy-3-methoxycinnamate: COC1=C(C=CC(=C1)C=CC(=O)O)O
# SMILES for trans-Citral: CC(=CCCC(=CC=O)C)C
# SMILES for Selenide: [Se-2]
# SMILES for Pyromucic acid: C1=COC(=C1)C(=O)O
# SMILES for Aminoformic acid: C(=O)(N)O
# SMILES for Benzoylaminoacetic acid: C1=CC=C(C=C1)C(=O)NCC(=O)O
# SMILES for Phaseolunatin: CC(C)(C#N)OC1C(C(C(C(O1)CO)O)O)O
# SMILES for 1,2-Benzenedicarboxylic acid: C1=CC=C(C(=C1)C(=O)O)C(=O)O
# SMILES for Stachyose: C(C1C(C(C(C(O1)OCC2C(C(C(C(O2)OCC3C(C(C(C(O3)OC4(C(C(C(O4)CO)O)O)CO)O)O)O)O)O)O)O)O)O)O
# SMILES for 2-Propenamide: C=CC(=O)N
# SMILES for Pentamethylenediamine: C(CCN)CCN
# SMILES for Dulcose: C(C(C(C(C(CO)O)O)O)O)O
# SMILES for Levanbiose: C(C1C(C(C(O1)(CO)OCC2C(C(C(O2)(CO)O)O)O)O)O)O
# SMILES for Xanthosine: C1=NC2=C(N1C3C(C(C(O3)CO)O)O)NC(=O)NC2=O
# SMILES for (3S)-3-Hydroxybutan-2-one: CC(C(=O)C)O
# SMILES for 2-Deoxy-D-ribose: C(C=O)C(C(CO)O)O
# SMILES for Dodecanoyl-CoA: CCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for Isopropyl alcohol: CC(C)O
# SMILES for FMNH2: CC1=CC2=C(C=C1C)N(C3=C(N2)C(=O)NC(=O)N3)CC(C(C(COP(=O)(O)O)O)O)O
# SMILES for L-5-Pyrrolidone-2-carboxylic acid: C1CC(=O)NC1C(=O)O
# SMILES for Desthiobiotin: CC1C(NC(=O)N1)CCCCCC(=O)O
# SMILES for cis-Geranyl-CoA: CC(=CCCC(=CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O)C)C
# SMILES for L-Histidinal: C1=C(NC=N1)CC(C=O)N
# SMILES for Maltooligosaccharide: C(C1C(C(C(C(O1)OC2C(OC(C(C2O)O)OC3C(OC(C(C3O)O)O)CO)CO)O)O)O)O
# SMILES for Octanoyl-CoA: CCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for L-Thiocysteine: C(C(C(=O)O)N)SS
# SMILES for Pseudouridine: C1=C(C(=O)NC(=O)N1)C2C(C(C(O2)CO)O)O
# SMILES for dTDP-D-galactose: CC1=CN(C(=O)NC1=O)C2CC(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(C(O3)CO)O)O)O)O
# SMILES for 2-Oxo-2-phenylacetate: C1=CC=C(C=C1)C(=O)C(=O)O
# SMILES for Methylmalonic acid: CC(C(=O)O)C(=O)O
# SMILES for Porphyrinogen IX: CC1=C(C2=CC3=NC(=CC4=NC(=CC5=C(C(=C(N5)C=C1N2)C=C)C)C(=C4CCC(=O)O)C)C(=C3C)CCC(=O)O)C=C
# SMILES for (2E,4Z)-2-Aminohexa-2,4-dienedioic acid: C(=CC(=O)O)C=C(C(=O)O)N
# SMILES for (2S,3S)-2-Methylcitric acid: CC(C(=O)O)C(CC(=O)O)(C(=O)O)O
# SMILES for Methylmaleic acid: CC(=CC(=O)O)C(=O)O
# SMILES for beta-Ketoadipyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CC(=O)CCC(=O)O)O
# SMILES for 2-Aminobenzoyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C4=CC=CC=C4N)O
# SMILES for D-alpha-Amino-beta-phenylpropionic acid: C1=CC=C(C=C1)CC(C(=O)O)N
# SMILES for D-Xylono-1,5-lactone: C1C(C(C(C(=O)O1)O)O)O
# SMILES for L-Cystathionine: C(CSCC(C(=O)O)N)C(C(=O)O)N
# SMILES for (S)(+)-Allantoin: C1(C(=O)NC(=O)N1)NC(=O)N
# SMILES for 2',3'-Cyclic AMP: C1=NC(=C2C(=N1)N(C=N2)C3C4C(C(O3)CO)OP(=O)(O4)O)N
# SMILES for 2',3'-Cyclic CMP: C1=CN(C(=O)N=C1N)C2C3C(C(O2)CO)OP(=O)(O3)[O-]
# SMILES for 2',3'-Cyclic UMP: C1=CN(C(=O)NC1=O)C2C3C(C(O2)CO)OP(=O)(O3)O
# SMILES for (S)-2-Aminobutyric acid: CCC(C(=O)O)N
# SMILES for Oxaloacetamide: C(C(=O)C(=O)O)C(=O)N
# SMILES for Mercaptopurine: C1=NC2=C(N1)C(=S)N=CN2
# SMILES for (2E)-4-Carboxybut-2-enoyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C=CCC(=O)O)O
# SMILES for L-Rhamnofuranose: CC(C1C(C(C(O1)O)O)O)O
# SMILES for Trimethylene glycol: C(CO)CO
# SMILES for Dihydrosirohydrochlorin: CC1(C(C2=CC3=NC(=CC4=C(C(=C(N4)CC5=C(C(=C(N5)C=C1N2)CC(=O)O)CCC(=O)O)CCC(=O)O)CC(=O)O)C(C3(C)CC(=O)O)CCC(=O)O)CCC(=O)O)CC(=O)O
# SMILES for (2Z,4Z)-Hexa-2,4-dienedioic acid: C(=CC(=O)O)C=CC(=O)O
# SMILES for 2-Hydroxymuconate: C(=CC(=O)O)C=C(C(=O)[O-])[O-]
# SMILES for (2S)-2-Isopropylmalic acid: CC(C)C(CC(=O)O)(C(=O)O)O
# SMILES for alpha-Phenylacetamide: C1=CC=C(C=C1)CC(=O)N
# SMILES for 3-Fumarylpyruvate: C(C(=O)C=CC(=O)O)C(=O)C(=O)O
# SMILES for Butanoyl phosphate: CCCC(=O)OP(=O)(O)O
# SMILES for Perillaldehyde: CC(=C)C1CCC(=CC1)C=O
# SMILES for Myristoyl-CoA: CCCCCCCCCCCCCC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for (2R)-2-Hydroxy-2-methylbutanedioate: CC(CC(=O)[O-])(C(=O)[O-])O
# SMILES for beta-Isopropylmaleate: CC(C)C(=CC(=O)O)C(=O)O
# SMILES for 3-Dehydroshikimate: C1C(C(C(=O)C=C1C(=O)O)O)O
# SMILES for N-Carbamoyl-beta-alanine: C(CNC(=O)N)C(=O)O
# SMILES for 4-Guanidinobutanal: C(CC=O)CN=C(N)N
# SMILES for 6-Carboxyhexanoate: C(CCC(=O)O)CCC(=O)O
# SMILES for 2-Hydroxyisobutyronitrile: CC(C)(C#N)O
# SMILES for D-Glucurone: C1(C2C(C(C(=O)O2)O)OC1O)O
# SMILES for Indole-3-acetamide: C1=CC=C2C(=C1)C(=CN2)CC(=O)N
# SMILES for N-Acetyl-D-muramoate: CC(C(=O)O)OC1C(C(OC(C1O)CO)O)NC(=O)C
# SMILES for Succinylbenzoate: C1=CC=C(C(=C1)C(=O)CCC(=O)O)C(=O)O
# SMILES for 1-(5-Phospho-beta-D-ribosyl)-ATP: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)N=CN(C2=N)C4C(C(C(O4)COP(=O)(O)O)O)O
# SMILES for 1-(5-Phospho-beta-D-ribosyl)-AMP: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)O)O)O)N=CN(C2=N)C4C(C(C(O4)COP(=O)(O)O)O)O
# SMILES for 2,5-Didehydro-D-gluconic acid: C(C(=O)C(C(C(=O)C(=O)O)O)O)O
# SMILES for 4-Imidazoleacetate: C1=C(NC=N1)CC(=O)O
# SMILES for Propionyl phosphate: CCC(=O)OP(=O)(O)O
# SMILES for 2-Hydroxymethylnaphthalene: C1=CC=C2C=C(C=CC2=C1)CO
# SMILES for Isovaleryl-CoA: CC(C)CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for N4-Acetylaminobutanoate: CC(=O)NCCCC(=O)O
# SMILES for 4-Hydroxybenzoyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C4=CC=C(C=C4)O)O
# SMILES for L-erythro-7,8-Dihydrobiopterin: CC(C(C1=NC2=C(NC1)N=C(NC2=O)N)O)O
# SMILES for D-Allose 6-phosphate: C(C(C(C(C(C=O)O)O)O)O)OP(=O)(O)O
# SMILES for L-Methionine S-oxide: CS(=O)CCC(C(=O)O)N
# SMILES for L-Rhamno-1,4-lactone: CC(C1C(C(C(=O)O1)O)O)O
# SMILES for N-Acetyl-D-muramoyl-L-alanine: CC(C(=O)O)NC(=O)C(C)OC1C(C(OC(C1O)CO)O)NC(=O)C
# SMILES for Thiamine triphosphate: CC1=C(SC=[N+]1CC2=CN=C(N=C2N)C)CCOP(=O)(O)OP(=O)(O)OP(=O)(O)O
# SMILES for (R,R)-2,3-Butylene glycol: CC(C(C)O)O
# SMILES for (2S,3S)-Butane-2,3-diol: CC(C(C)O)O
# SMILES for 2-Formylbenzoate: C1=CC=C(C(=C1)C=O)C(=O)[O-]
# SMILES for 2-Oxohept-3-ene-1,7-dioate: C(CC(=O)O)C=CC(=O)C(=O)O
# SMILES for 3-Dehydro-D-erythronate: C(C(=O)C(C(=O)[O-])O)O
# SMILES for 3-Hydroxybenzaldehyde: C1=CC(=CC(=C1)O)C=O
# SMILES for Dimethylacryloyl-CoA: CC(=CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O)C
# SMILES for 4-Guanidinobutanamide: C(CC(=O)N)CN=C(N)N
# SMILES for L-4-Aspartyl phosphate: C(C(C(=O)O)N)C(=O)OP(=O)(O)O
# SMILES for 5-(Methylsulfanyl)-D-ribose: CSCC1C(C(C(O1)O)O)O
# SMILES for 5-Phosphoribosyl-1-amine: C(C1C(C(C(O1)N)O)O)OP(=O)(O)O
# SMILES for 5,6-Dimethylbenzimidazole: CC1=CC2=C(C=C1C)N=CN2
# SMILES for 1-(beta-D-Ribofuranosyl)nicotinamide: C1=CC(=C[N+](=C1)C2C(C(C(O2)CO)O)O)C(=O)N
# SMILES for 4-(2-Carboxyphenyl)-4-oxobutanoyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CCC(=O)C4=CC=CC=C4C(=O)O)O
# SMILES for 2-Oxoethylphosphonate: C(C=O)P(=O)(O)O
# SMILES for Shikimate 5-phosphate: C1C(C(C(C=C1C(=O)O)OP(=O)(O)O)O)O
# SMILES for dTDP-beta-L-pneumose: CC1C(C(C(C(O1)OP(=O)(O)OP(=O)(O)OCC2C(CC(O2)N3C=C(C(=O)NC3=O)C)O)O)O)O
# SMILES for (R)-1-Amino-2-propanol: CC(CN)O
# SMILES for (2E)-Dodecenoyl-CoA: CCCCCCCCCC=CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for (E)-3-Methylglutaconyl-1-CoA: CC(=CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O)CC(=O)O
# SMILES for 3-Phosphooxypyruvate: C(C(=O)C(=O)[O-])OP(=O)([O-])[O-]
# SMILES for Coproporphyrinogen III: CC1=C2CC3=C(C(=C(N3)CC4=C(C(=C(N4)CC5=C(C(=C(N5)CC(=C1CCC(=O)O)N2)C)CCC(=O)O)C)CCC(=O)O)CCC(=O)O)C
# SMILES for 5-Oxopentanoic acid: C(CC=O)CC(=O)O
# SMILES for L-2,4-Diaminobutyrate: C(CN)C(C(=O)O)N
# SMILES for (S)-3-Aminoisobutyric acid: CC(CN)C(=O)O
# SMILES for L-Glutamate 5-phosphate: C(CC(=O)OP(=O)(O)O)C(C(=O)O)N
# SMILES for L-Xylulose 5-phosphate: C(C(C(C(=O)CO)O)O)OP(=O)(O)O
# SMILES for dTDP-beta-L-rhamnose: CC1C(C(C(C(O1)OP(=O)(O)OP(=O)(O)OCC2C(CC(O2)N3C=C(C(=O)NC3=O)C)O)O)O)O
# SMILES for 2-Methyl-3-acetoacetyl-CoA: CC(C(=O)C)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for 2-Methylcrotanoyl-CoA: CC=C(C)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for 4-Nitrophenyl phosphate: C1=CC(=CC=C1[N+](=O)[O-])OP(=O)(O)O
# SMILES for 5-Amino-1-(5-phospho-beta-D-ribosyl)imidazole: C1=C(N(C=N1)C2C(C(C(O2)COP(=O)(O)O)O)O)N
# SMILES for gamma-D-Galactonolactone: C(C(C1C(C(C(=O)O1)O)O)O)O
# SMILES for 4-Phosphoerythronate: C(C(C(C(=O)O)O)O)OP(=O)(O)O
# SMILES for L-Erythrulose 1-phosphate: C(C(C(=O)COP(=O)(O)O)O)O
# SMILES for (2S)-2,3-Diaminopropanoic acid: C(C(C(=O)O)N)N
# SMILES for L-Arginosuccinic acid: C(CC(C(=O)O)N)CN=C(N)NC(CC(=O)O)C(=O)O
# SMILES for Oxaloglycolate: C(C(=O)C(=O)O)(C(=O)O)O
# SMILES for Methylacrylyl-CoA: CC(=C)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for (2E,6E)-Farnesal: CC(=CCCC(=CCCC(=CC=O)C)C)C
# SMILES for L(-)-5-Formyl-5,6,7,8-tetrahydrofolic acid: C1C(N(C2=C(N1)N=C(NC2=O)N)C=O)CNC3=CC=C(C=C3)C(=O)NC(CCC(=O)O)C(=O)O
# SMILES for (R)-4'-Phosphopantothenate: CC(C)(COP(=O)(O)O)C(C(=O)NCCC(=O)O)O
# SMILES for Indole-3-glycerol phosphate: C1=CC=C2C(=C1)C(=CN2)C(C(COP(=O)(O)O)O)O
# SMILES for (S)-2-Amino-3-oxobutanoic acid: CC(=O)C(C(=O)O)N
# SMILES for S-(5-Deoxy-D-ribos-5-yl)-L-homocysteine: C(CSCC1C(C(C(O1)O)O)O)C(C(=O)O)N
# SMILES for Inositol 4-phosphate: C1(C(C(C(C(C1O)O)OP(=O)(O)O)O)O)O
# SMILES for (3R)-3-Hydroxybutanoyl-CoA: CC(CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O)O
# SMILES for 1-Pyrroline 2-carboxylate: C1CC(=NC1)C(=O)O
# SMILES for CoM: C(CS(=O)(=O)O)S
# SMILES for (2E,4Z)-3-Chlorohexa-2,4-dienedioic acid: C(=CC(=O)O)C(=CC(=O)O)Cl
# SMILES for 5-Oxo-4,5-dihydrofuran-2-acetate: C1C=C(OC1=O)CC(=O)O
# SMILES for 2-(4-Hydroxyphenyl)-2-oxoacetate: C1=CC(=CC=C1C(=O)C(=O)O)O
# SMILES for D-Erythrulose 4-phosphate: C(C(C(=O)CO)O)OP(=O)(O)O
# SMILES for 1,4-Dihydroxy-2-naphthoic acid: C1=CC=C2C(=C1)C(=CC(=C2O)C(=O)O)O
# SMILES for 4,5-Dihydro-4-oxo-5-imidazolepropanoate: C1=NC(C(=O)N1)CCC(=O)O
# SMILES for 2,3-Pyridinedicarboxylic acid: C1=CC(=C(N=C1)C(=O)O)C(=O)O
# SMILES for L-Glutamate 1-semialdehyde: C(CC(=O)O)C(C=O)N
# SMILES for (S)-4-Hydroxymandelonitrile: C1=CC(=CC=C1C(C#N)O)O
# SMILES for Glucosaminate: C(C(C(C(C(C(=O)O)N)O)O)O)O
# SMILES for 2-(4-Hydroxyphenyl)acetaldehyde: C1=CC(=CC=C1CC=O)O
# SMILES for 2-Oxoarginine: C(CC(=O)C(=O)O)CN=C(N)N
# SMILES for D-Tagatose 1,6-bisphosphate: C(C1C(C(C(O1)(COP(=O)(O)O)O)O)O)OP(=O)(O)O
# SMILES for Adenylosuccinic acid: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)O)O)NC(CC(=O)O)C(=O)O
# SMILES for 2-Aminomuconate 6-semialdehyde: C(=CC=O)C=C(C(=O)O)N
# SMILES for 2-Dehydro-3-deoxy-D-arabinonic acid: C(C(CO)O)C(=O)C(=O)O
# SMILES for 2-Dehydro-3-deoxy-L-fuconate: CC(C(CC(=O)C(=O)[O-])O)O
# SMILES for N1-(5-Phospho-beta-D-ribosyl)glycinamide: C(C1C(C(C(O1)NC(=O)CN)O)O)OP(=O)(O)O
# SMILES for 1-Pyrroline-5-carboxylate: C1CC(N=C1)C(=O)O
# SMILES for (S)-2,3,4,5-Tetrahydropyridine-2,6-dicarboxylate: C1CC(N=C(C1)C(=O)O)C(=O)O
# SMILES for 2-Dehydro-3-deoxy-L-rhamnonate: CC(C(CC(=O)C(=O)O)O)O
# SMILES for L-myo-Inositol 1-phosphate: C1(C(C(C(C(C1O)O)OP(=O)(O)O)O)O)O
# SMILES for 2,3-Dihydroxy-isovaleric acid: CC(C)(C(C(=O)O)O)O
# SMILES for Protocatechuatealdehyde: C1=CC(=C(C=C1CC=O)O)O
# SMILES for 5-Amino-4-imidazolecarboxyamide: C1=NC(=C(N1)C(=O)N)N
# SMILES for 5-Oxopent-3-ene-1,2,5-tricarboxylate: C(C(C=CC(=O)C(=O)O)C(=O)O)C(=O)O
# SMILES for (S)-2-Amino-6-oxohexanoate: C(CC=O)CC(C(=O)O)N
# SMILES for N-Pantothenoylcysteine: CC(C)(CO)C(C(=O)NCCC(=O)NC(CS)C(=O)O)O
# SMILES for 3-Methyl-cis,cis-muconate: CC(=CC(=O)O)C=CC(=O)O
# SMILES for (R)-1-Aminopropan-2-yl phosphate: CC(CN)OP(=O)(O)O
# SMILES for (6S)-H4PteGlu3: C1C(NC2=C(N1)N=C(NC2=O)N)CNC3=CC=C(C=C3)C(=O)NC(CCC(=O)NC(CCC(=O)NC(CCC(=O)O)C(=O)O)C(=O)O)C(=O)O
# SMILES for Solanesyl diphosphate: CC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCOP(=O)(O)OP(=O)(O)O)C)C)C)C)C)C)C)C)C
# SMILES for (2S,3S)-2,3-Dihydroxy-2,3-dihydroxybenzoate: C1=CC(C(C(=C1)C(=O)O)O)O
# SMILES for 2-Oxo-3-hydroxyisovalerate: CC(C)(C(=O)C(=O)[O-])O
# SMILES for 5-Carboxymethyl-2-hydroxymuconate: C(C(=CC=C(C(=O)O)O)C(=O)O)C(=O)O
# SMILES for S-Methyl-5-thio-5-deoxy-D-ribose 1-phosphate: CSCC1C(C(C(O1)OP(=O)(O)O)O)O
# SMILES for all-trans-Heptaprenyl diphosphate: CC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCOP(=O)(O)OP(=O)(O)O)C)C)C)C)C)C)C
# SMILES for 2-Oxo-4-methyl-3-carboxypentanoate: CC(C)C(C(=O)C(=O)O)C(=O)O
# SMILES for 5-Fluorodeoxyuridine monophosphate: C1C(C(OC1N2C=C(C(=O)NC2=O)F)COP(=O)(O)O)O
# SMILES for N-Acetylmannosamine 6-phosphate: CC(=O)NC1C(C(C(OC1O)COP(=O)(O)O)O)O
# SMILES for (2R)-2,3-Dihydroxy-3-methylbutanoic acid: CC(C)(C(C(=O)O)O)O
# SMILES for (3R,5S)-3-Hydroxy-1-pyrroline-5-carboxylate: C1C(C=NC1C(=O)O)O
# SMILES for 1-Pyrroline-4-hydroxy-2-carboxylate: C1C(CN=C1C(=O)O)O
# SMILES for HET: CC1=C(SC=N1)CCO
# SMILES for 3beta,17beta-Dihydroxy-5-androstene: CC12CCC3C(C1CCC2O)CC=C4C3(CCC(C4)O)C
# SMILES for N-(5-Phosphoribosyl)anthranilic acid: C1=CC=C(C(=C1)C(=O)O)NC2C(C(C(O2)COP(=O)(O)O)O)O
# SMILES for HET-P: CC1=C(SC=N1)CCOP(=O)(O)O
# SMILES for 6,7-Dimethyl-8-(D-ribityl)lumazine: CC1=C(N(C2=NC(=O)NC(=O)C2=N1)CC(C(C(CO)O)O)O)C
# SMILES for (3S)-3-Carboxy-3-hydroxypropionyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CC(C(=O)O)O)O
# SMILES for 3-Deoxy-D-glycero-hexo-2,5-diulosonic acid: C(C(C(=O)CO)O)C(=O)C(=O)O
# SMILES for N-[(R)-4'-Phosphopantothenoyl]-L-cysteine: CC(C)(COP(=O)(O)O)C(C(=O)NCCC(=O)NC(CS)C(=O)O)O
# SMILES for N2-Formyl-N1-(5-phospho-beta-D-ribosyl)glycinamide: C(C1C(C(C(O1)NC(=O)CNC=O)O)O)OP(=O)(O)O
# SMILES for N5,N10-Methylenetetrahydromethanopterin: CC1C2C(N(CN2C3=C(N1)N=C(NC3=O)N)C4=CC=C(C=C4)CC(C(C(COC5C(C(C(O5)COP(=O)(O)OC(CCC(=O)O)C(=O)O)O)O)O)O)O)C
# SMILES for N-Acetyl-LL-2,6-diaminoheptanedioate: CC(=O)NC(CCCC(C(=O)O)N)C(=O)O
# ...
# SMILES for 5-Fluorouridine: C1=C(C(=O)NC(=O)N1C2C(C(C(O2)CO)O)O)F
# SMILES for 5-Fluorouridine monophosphate: C1=C(C(=O)NC(=O)N1C2C(C(C(O2)COP(=O)(O)O)O)O)F
# SMILES for 5'-Deoxy-5-fluorocytidine: CC1C(C(C(O1)N2C=C(C(=NC2=O)N)F)O)O
# SMILES for 5-Deoxy-alpha-D-ribose-1-phosphate: CC1C(C(C(O1)OP(=O)(O)O)O)O
# SMILES for beta-D-Ribofuranose: C(C1C(C(C(O1)O)O)O)O
# SMILES for 7-Aminomethyl-7-deazaguanine: C1=C(C2=C(N1)N=C(NC2=O)N)CN
# SMILES for beta-D-Fructofuranosyl-6-O-phosphono-alpha-D-glucopyranoside: C(C1C(C(C(O1)(CO)OC2C(C(C(C(O2)COP(=O)(O)O)O)O)O)O)O)O
# SMILES for MurNAc 6-phosphate: CC(C(=O)O)OC1C(C(OC(C1O)COP(=O)(O)O)O)NC(=O)C
# SMILES for (2Z,6E)-Farnesyl diphosphate: CC(=CCCC(=CCCC(=CCOP(=O)(O)OP(=O)(O)O)C)C)C
# SMILES for Dehypoxanthine futalosine: C1=CC(=CC(=C1)C(=O)O)C(=O)CCC2C(C(C(O2)O)O)O
# SMILES for 2-(2'-Methylthio)ethylmalate: CSCCC(CC(=O)O)(C(=O)O)O
# SMILES for 3-(2'-Methylthio)ethylmalate: CSCCC(C(C(=O)O)O)C(=O)O
# SMILES for 2-(3'-Methylthio)propylmalate: CSCCCC(CC(=O)O)(C(=O)O)O
# SMILES for 3-(3'-Methylthio)propylmalate: CSCCCC(C(C(=O)O)O)C(=O)O
# SMILES for 2-(4'-Methylthio)butylmalate: CSCCCCC(CC(=O)O)(C(=O)O)O
# SMILES for 3-(4'-Methylthio)butylmalate: CSCCCCC(C(C(=O)O)O)C(=O)O
# SMILES for 2-(5'-Methylthio)pentylmalate: CSCCCCCC(CC(=O)O)(C(=O)O)O
# SMILES for 3-(5'-Methylthio)pentylmalate: CSCCCCCC(C(C(=O)O)O)C(=O)O
# SMILES for 2-(6'-Methylthio)hexylmalate: CSCCCCCCC(CC(=O)O)(C(=O)O)O
# SMILES for 3-(6'-Methylthio)hexylmalate: CSCCCCCCC(C(C(=O)O)O)C(=O)O
# SMILES for 2-(7'-Methylthio)heptylmalate: CSCCCCCCCC(CC(=O)O)(C(=O)O)O
# SMILES for 3-(7'-Methylthio)heptylmalate: CSCCCCCCCC(C(C(=O)O)O)C(=O)O
# SMILES for (25S)-3alpha,7alpha,12alpha-Trihydroxy-5beta-cholestan-26-oyl-CoA: CC(CCCC(C)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O)C4CCC5C4(C(CC6C5C(CC7C6(CCC(C7)O)C)O)O)C
# SMILES for (25R)-3alpha,7alpha-Dihydroxy-5beta-cholestanoyl-CoA: CC(CCCC(C)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O)C4CCC5C4(CCC6C5C(CC7C6(CCC(C7)O)C)O)C
# SMILES for (25S)-3alpha,7alpha-Dihydroxy-5beta-cholestanoyl-CoA: CC(CCCC(C)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O)C4CCC5C4(CCC6C5C(CC7C6(CCC(C7)O)C)O)C
# SMILES for Cobalt-factor III: CC1=C2C(C(C(=N2)C=C3C(C(C(=CC4=NC(=CC5=C(C(=C1[N-]5)CC(=O)O)CCC(=O)O)C(=C4CC(=O)O)CCC(=O)O)[N-]3)CCC(=O)O)(C)CC(=O)O)CCC(=O)O)(C)CC(=O)O.[Co]
# SMILES for ditrans,octacis-Undecaprenyl phosphate: CC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCOP(=O)(O)O)C)C)C)C)C)C)C)C)C)C)C
# SMILES for 8-Oxogeranial: CC(=CC=O)CCC=C(C)C=O
# SMILES for N-Adpt: CC(=O)NC(CC[P+](=O)O)C(=O)O
# SMILES for N-Acetylphinothricin: CC(=O)NC(CCP(=O)(C)O)C(=O)O
# SMILES for (2S)-2-Amino-4-(hydroxyphosphinyl)butanoic acid: C(C[P+](=O)O)C(C(=O)O)N
# SMILES for Ethylmalonyl coenzyme A: CCC(C(=O)O)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for 5'-Phosphoguanylyl(3'->5')guanosine: C1=NC2=C(N1C3C(C(C(O3)COP(=O)([O-])OC4C(OC(C4O)N5C=NC6=C5N=C(NC6=O)N)COP(=O)([O-])[O-])O)O)N=C(NC2=O)N
# SMILES for Ethylnitronate: CC=[N+]([O-])[O-]
# SMILES for D-Allulose 6-phosphate: C(C(C(C(C(=O)CO)O)O)O)OP(=O)(O)O
# SMILES for (-)-Secoisolariciresinol: COC1=C(C=CC(=C1)CC(CO)C(CC2=CC(=C(C=C2)O)OC)CO)O
# SMILES for Molybdenum cofactor: C(C1C(=C(C2C(O1)NC3=C(N2)C(=O)NC(=N3)N)[S-])[S-])OP(=O)(O)O.O=[Mo+2]=O
# SMILES for cPMP: C1C2C(C(C3C(O2)NC4=C(N3)C(=O)NC(=N4)N)(O)O)OP(=O)(O1)O
# SMILES for (2Z,6Z,10Z,14Z,18Z,22Z,26Z,30Z,34E)-Decaprenyl diphosphate: CC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCOP(=O)(O)OP(=O)(O)O)C)C)C)C)C)C)C)C)C)C
# SMILES for Methylsuccinyl-coenzyme A: CC(CC(=O)O)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for 3,4-Dihydroxyaniline: C1=CC(=C(C=C1N)O)O
# SMILES for 2-Hydroxy-2-methylbutanenitrile: CCC(C)(C#N)O
# SMILES for Methylseleninate: C[Se](=O)O
# SMILES for (R)-2-[(R)-2-Aminopropanoyloxy]propanoic acid: CC(C(=O)OC(C)C(=O)O)N
# SMILES for UDP-2,3-diacetamido-2,3-dideoxy-alpha-D-glucuronic acid: CC(=O)NC1C(C(OC(C1O)C(=O)O)OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)NC(=O)C
# SMILES for 8,8'-Diapocarotene-8,8'-dial: CC(=CC=CC=C(C)C=CC=C(C)C=O)C=CC=C(C)C=O
# SMILES for (4R)-4-Hydroxy-2,6,6-trimethylcyclohex-1-en-1-carboxaldehyde: CC1=C(C(CC(C1)O)(C)C)C=O
# SMILES for UDP-2,3-diacetamido-2,3-dideoxy-alpha-D-mannuronic acid: CC(=O)NC1C(C(OC(C1O)C(=O)O)OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)NC(=O)C
# SMILES for Demethylmenaquinol: CC(=CCCC(=CCC1=C(C2=CC=CC=C2C(=C1)O)O)C)C
# SMILES for Adenylyl-molybdopterin: C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OCC4C(=C(C5C(O4)NC6=C(N5)C(=O)NC(=N6)N)S)S)O)O)N
# SMILES for tritrans,heptacis-Undecaprenyl diphosphate: CC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCOP(=O)(O)OP(=O)(O)O)C)C)C)C)C)C)C)C)C)C)C
# SMILES for Molybdopterin guanine dinucleotide cofactor: C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OCC4C(=C(C5C(O4)NC6=C(N5)C(=O)NC(=N6)N)[S-])[S-])O)O)N=C(NC2=O)N.O=[Mo+2]=O
# SMILES for (+)-Inositol: C1(C(C(C(C(C1O)O)O)O)O)O
# SMILES for Secophenol: CC1=C(C=C(C=C1)O)CCC2C3CCC(=O)C3(CCC2=O)C
# SMILES for 3-Oxo-5,6-didehydrosuberoyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CC(=O)CC=CCC(=O)O)O
# SMILES for 2-Oxepin-2(3H)-ylideneacetyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C=C4CC=CC=CO4)O
# SMILES for 2-(1,2-Epoxy-1,2-dihydrophenyl)acetyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)CC45C=CC=CC4O5)O
# SMILES for (2R)-Ethylmalonyl-CoA: CCC(C(=O)O)C(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O
# SMILES for 6-Carboxytetrahydropterin: C1C(NC2=C(N1)N=C(NC2=O)N)C(=O)[O-]
# SMILES for cThz*-P: CC1=NC(SC1=CCOP(=O)([O-])[O-])C(=O)[O-]
# SMILES for cThz-P: CC1=C(SC(=N1)C(=O)[O-])CCOP(=O)([O-])[O-]
# SMILES for 7-Carboxy-7-deazaguanine: C1=C(C2=C(N1)N=C(NC2=O)N)C(=O)O
# SMILES for 5-Androstene-3,17-dione: CC12CCC3C(C1CCC2=O)CC=C4C3(CCC(=O)C4)C
# SMILES for HTPA: C1C(CC(=NC1C(=O)O)C(=O)O)O
# SMILES for Amino-HMP: CC1=NC=C(C(=N1)N)CN
# SMILES for Tetraprenyl-beta-curcumene: CC1=CCC(=CC1)C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C
# SMILES for 2-Oxo-4-phenylbutanoate: C1=CC=C(C=C1)CCC(=O)C(=O)O
# SMILES for UDP-2,4-diacetamido-2,4,6-trideoxy-alpha-D-glucopyranose: CC1C(C(C(C(O1)OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)NC(=O)C)O)NC(=O)C
# SMILES for UDP-2-acetamido-3-amino-2,3-dideoxy-alpha-D-glucuronate: CC(=O)NC1C(C(C(OC1OP(=O)([O-])OP(=O)([O-])OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O)C(=O)[O-])O)[NH3+]
# SMILES for Biotin sulfoxide: C1C2C(C(S1=O)CCCCC(=O)O)NC(=O)N2
# SMILES for UDP-3-keto-GlcNAcA: CC(=O)NC1C(OC(C(C1=O)O)C(=O)O)OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=CC(=O)NC3=O)O)O
# SMILES for Methylphosphonate: CP(=O)([O-])[O-]
# SMILES for tritrans,heptacis-Undecaprenyl phosphate: CC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCOP(=O)(O)O)C)C)C)C)C)C)C)C)C)C)C
# SMILES for N,N'-Diacetyl-alpha-D-bacillosaminyldiphospho-tritrans,heptacis-undecaprenol: CC1C(C(C(C(O1)OP(=O)(O)OP(=O)(O)OCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)CCC=C(C)C)NC(=O)C)O)NC(=O)C
# SMILES for alpha-D-Ribose 1-methylphosphonate 5-triphosphate: CP(=O)(O)OC1C(C(C(O1)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O
# SMILES for 2-Oxoglutaroyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C(=O)CCC(=O)O)O
# SMILES for GDP-alpha-D-perosamine: CC1C(C(C(C(O1)OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=NC4=C3N=C(NC4=O)N)O)O)O)O)N
# SMILES for TC-AMP: CC(C(C(=O)O)NC(=O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)O)O
# SMILES for 3-Benzylmalate: C1=CC=C(C=C1)CC(C(C(=O)[O-])O)C(=O)[O-]
# SMILES for meso-2,3-Butanediol: CC(C(C)O)O
# SMILES for 3-Dehydro-D-glucose 6-phosphate: C(C1C(C(=O)C(C(O1)O)O)O)OP(=O)([O-])[O-]
# SMILES for Crotonobetainyl-CoA: CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCSC(=O)C=CC[N+](C)(C)C)O
# SMILES for L-Carnitinyl-CoA: CC(C)(COP(=O)([O-])OP(=O)([O-])OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)([O-])[O-])C(C(=O)NCCC(=O)NCCSC(=O)CC(C[N+](C)(C)C)O)O
# SMILES for 6-Amino-6-deoxyfutalosine: C1=CC(=CC(=C1)C(=O)[O-])C(=O)CCC2C(C(C(O2)N3C=NC4=C(N=CN=C43)N)O)O
# SMILES for 2,4-Didehydro-3-deoxy-L-rhamnonate: CC(C(=O)CC(=O)C(=O)[O-])O
# SMILES for 6-Deoxy-6-sulfo-D-fructose: C(C1C(C(C(O1)(CO)O)O)O)S(=O)(=O)[O-]
# SMILES for 6-Deoxy-6-sulfo-D-fructose 1-phosphate: C(C1C(C(C(O1)(COP(=O)([O-])[O-])O)O)O)S(=O)(=O)[O-]
# SMILES for HIP-CoA: CC12CCC(=O)C(C1CCC2=O)CCC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)OP(=O)(O)O)O
# SMILES for 3-(Methylsulfanyl)propanoyl-CoA: CC(C)(COP(=O)([O-])OP(=O)([O-])OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)([O-])[O-])C(C(=O)NCCC(=O)NCCSC(=O)CCSC)O
# SMILES for 4-O-beta-D-Mannopyranosyl-N-acetyl-D-glucosamine: CC(=O)NC1C(C(C(OC1O)CO)OC2C(C(C(C(O2)CO)O)O)O)O
# SMILES for 3beta-Hydroxy-8'-apo-beta-carotenal: CC1=C(C(CC(C1)O)(C)C)C=CC(=CC=CC(=CC=CC=C(C)C=CC=C(C)C=O)C)C
# SMILES for D-Galactaro-1,4-lactone: C1(C(C(=O)OC1C(C(=O)O)O)O)O
# SMILES for L-Dihydroanticapsin: C1CC(C2C(C1CC(C(=O)O)N)O2)O
# SMILES for Anticapsin: C1CC(=O)C2C(C1CC(C(=O)O)N)O2
# SMILES for (4R)-2-Methyl-6-methyleneocta-2,7-dien-4-ol: CC(=CC(CC(=C)C=C)O)C
# SMILES for 2-Methyl-6-methyleneocta-2,7-dien-4-one: CC(=CC(=O)CC(=C)C=C)C
# SMILES for 4-(Hydroxymethyl)-2-furancarboxaldehyde phosphate: C1=C(OC=C1COP(=O)([O-])[O-])C=O
# SMILES for 3-(Methylsulfanyl)acryloyl-CoA: CC(C)(COP(=O)([O-])OP(=O)([O-])OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)([O-])[O-])C(C(=O)NCCC(=O)NCCSC(=O)C=CSC)O
# SMILES for L-Alanyl-D-glutamate: CC(C(=O)NC(CCC(=O)O)C(=O)O)N
# SMILES for L-Alanyl-L-glutamate: CC(C(=O)NC(CCC(=O)O)C(=O)O)N
# SMILES for (2E)-4-{[(2S)-2-Amino-2-carboxyethyl]amino}-4-oxobut-2-enoate: C(C(C(=O)O)N)NC(=O)C=CC(=O)O
# SMILES for 3-{[(2E)-4-Amino-4-oxobut-2-enoyl]amino}-L-alanine: C(C(C(=O)O)N)NC(=O)C=CC(=O)N
# SMILES for Carboxyphosphate: C(=O)(O)OP(=O)(O)O
# SMILES for 8-Demethyl-8-alpha-L-rhamnosyltetracenomycin C: CC1C(C(C(C(O1)OC2=CC3=CC4=C(C(=C3C(=C2C(=O)OC)C)O)C(=O)C5(C(=O)C=C(C(C5(C4=O)O)O)OC)O)O)O)O
# SMILES for 8-Demethyl-8-(2-O-methyl-alpha-L-rhamnosyl)tetracenomycin C: CC1C(C(C(C(O1)OC2=CC3=CC4=C(C(=C3C(=C2C(=O)OC)C)O)C(=O)C5(C(=O)C=C(C(C5(C4=O)O)O)OC)O)OC)O)O
# SMILES for 8-Demethyl-8-(2,3-di-O-methyl-alpha-L-rhamnosyl)tetracenomycin C: CC1C(C(C(C(O1)OC2=CC3=CC4=C(C(=C3C(=C2C(=O)OC)C)O)C(=O)C5(C(=O)C=C(C(C5(C4=O)O)O)OC)O)OC)OC)O
# SMILES for 2-Hydroxypropyl-ThPP: CCC(C1=[N+](C(=C(S1)CCOP(=O)(O)OP(=O)(O)O)C)CC2=CN=C(N=C2N)C)O
# SMILES for (R)-N-Carbamyl-beta-aminoisobutyrate: CC(CNC(=O)N)C(=O)O
# SMILES for 5-(Aminomethyl)-3-furanmethanol phosphate: C1=C(OC=C1COP(=O)([O-])[O-])C[NH3+]
# SMILES for Epoxy-3E-H2HPP: C1CC(=CC(=O)C(=O)O)C2C(C1O)O2
# SMILES for Epoxy-4S-H4HPP: C1CC(C2C(C1CC(=O)C(=O)[O-])O2)O
# SMILES for 1,3,7-Trimethyl-5-hydroxyisourate: CN1C2=NC(=O)N(C2(C(=O)N(C1=O)C)O)C
# SMILES for Adenosylcobalamin 5'-phosphate: CC1=CC2=C(C=C1C)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)OP(=O)([O-])OC(C)CNC(=O)CCC4(C(C5C6(C(C(C(=N6)C(=C7C(C(C(=N7)C=C8C(C(C(=N8)C(=C4[N-]5)C)CCC(=O)N)(C)C)CCC(=O)N)(C)CC(=O)N)C)CCC(=O)N)(C)CC(=O)N)C)CC(=O)N)C)O.[CH2-]C1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)O.[Co+3]
# SMILES for 4-Hydroxy-3-methylbenzaldehyde: CC1=C(C=CC(=C1)C=O)O
# SMILES for 4-Hydroxy-m-toluate: CC1=C(C=CC(=C1)C(=O)O)O
# SMILES for 2-Methyl-trans-aconitate: CC(=C(CC(=O)[O-])C(=O)[O-])C(=O)[O-]
# SMILES for Coproheme III: CC1=C(C2=CC3=NC(=CC4=C(C(=C([N-]4)C=C5C(=C(C(=N5)C=C1[N-]2)C)CCC(=O)O)CCC(=O)O)C)C(=C3C)CCC(=O)O)CCC(=O)O.[Fe+2]
# SMILES for D-Erythritol 1-phosphate: C(C(C(COP(=O)(O)O)O)O)O
# SMILES for (8S)-3',8-Cyclo-7,8-dihydroguanosine 5'-triphosphate: C(C1C2(C(C(O1)N3C2NC4=C3N=C(NC4=O)N)O)O)OP(=O)(O)OP(=O)(O)OP(=O)(O)O
# SMILES for 3,8-Dideoxy-8-oxo-D-manno-octulosonate: C1C(C(C(OC1(C(=O)O)O)C(C=O)O)O)O
# SMILES for Kdo8N: C1C(C(C(OC1(C(=O)[O-])O)C(C[NH3+])O)O)O
# SMILES for beta-D-Mannopyranosyl-(1->2)-D-mannopyranose: C(C1C(C(C(C(O1)O)OC2C(C(C(C(O2)CO)O)O)O)O)O)O
# SMILES for dTDP-4-dehydro-alpha-D-xylose: CC1=CN(C(=O)NC1=O)C2CC(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(=O)CO3)O)O)O
# SMILES for dTDP-2-deoxy-4-keto-alpha-D-pentos-2-ene: CC1=CN(C(=O)NC1=O)C2CC(C(O2)COP(=O)(O)OP(=O)(O)OC3C=C(C(=O)CO3)O)O
# SMILES for dTDP-4-dehydro-2-deoxy-beta-L-xylose: CC1=CN(C(=O)NC1=O)C2CC(C(O2)COP(=O)(O)OP(=O)(O)OC3CC(C(=O)CO3)O)O
# SMILES for Valienol 1-phosphate: C1=C(C(C(C(C1OP(=O)(O)O)O)O)O)CO
# SMILES for GDP-valienol: C1=C(C(C(C(C1OP(=O)(O)OP(=O)(O)OCC2C(C(C(O2)N3C=NC4=C3N=C(NC4=O)N)O)O)O)O)O)CO
# SMILES for Molybdopterin cytosine dinucleotide cofactor: C1=CN(C(=O)N=C1N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(=C(C4C(O3)NC5=C(N4)C(=O)NC(=N5)N)[S-])[S-])O)O.O=[Mo+2]=O
# SMILES for alpha-D-Gal-(1->3)-alpha-D-GlcNAc-diphospho-ditrans,octacis-undecaprenol: CC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCCC(=CCOP(=O)(O)OP(=O)(O)OC1C(C(C(C(O1)CO)O)OC2C(C(C(C(O2)CO)O)O)O)NC(=O)C)C)C)C)C)C)C)C)C)C)C)C
# SMILES for 4-Hydroxybenzoyl-AMP: C1=CC(=CC=C1C(=O)OP(=O)(O)OCC2C(C(C(O2)N3C=NC4=C(N=CN=C43)N)O)O)O
# SMILES for Ni-sirohydrochlorin: CC1(C(C2=CC3=NC(=CC4=C(C(=C([N-]4)C=C5C(C(C(=N5)C=C1[N-]2)CCC(=O)[O-])(C)CC(=O)[O-])CC(=O)[O-])CCC(=O)[O-])C(=C3CC(=O)[O-])CCC(=O)[O-])CCC(=O)[O-])CC(=O)[O-].[Ni]
# SMILES for Ni-sirohydrochlorin a,c-diamide: CC1(C(C2=CC3=NC(=CC4=C(C(=C([N-]4)C=C5C(C(C(=N5)C=C1[N-]2)CCC(=O)[O-])(C)CC(=O)N)CC(=O)[O-])CCC(=O)[O-])C(=C3CC(=O)[O-])CCC(=O)[O-])CCC(=O)[O-])CC(=O)N.[Ni]
# SMILES for N-[(2S)-2-Amino-2-carboxyethyl]-L-glutamate: C(CC(=O)O)C(C(=O)O)NCC(C(=O)O)N
# SMILES for 4-Hydroxy-2,2'-bipyrrole-5-methanol: C1=CNC(=C1)C2=CC(=C(N2)CO)O
# SMILES for 3-Dehydro-L-erythronate: C(C(=O)C(C(=O)[O-])O)O
# SMILES for 2-Dehydro-D-erythronate: C(C(C(=O)C(=O)[O-])O)O
# SMILES for 2-Dehydro-L-erythronate: C(C(C(=O)C(=O)[O-])O)O
# SMILES for 5-Fluorouridine diphosphate: C1=C(C(=O)NC(=O)N1C2C(C(C(O2)COP(=O)(O)OP(=O)(O)O)O)O)F
# SMILES for 5-Fluorouridine triphosphate: C1=C(C(=O)NC(=O)N1C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)F
# SMILES for 5-Fluorodeoxyuridine diphosphate: C1C(C(OC1N2C=C(C(=O)NC2=O)F)COP(=O)(O)OP(=O)(O)O)O
# SMILES for 5-Fluorodeoxyuridine triphosphate: C1C(C(OC1N2C=C(C(=O)NC2=O)F)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O
# SMILES for Deaminated glutathione: C(CC(=O)NC(CS)C(=O)NCC(=O)O)C(=O)C(=O)O
# SMILES for Stearic acid: CCCCCCCCCCCCCCCCCC(=O)O
# SMILES for Lauric acid: CCCCCCCCCCCC(=O)O
# SMILES for Myristic acid: CCCCCCCCCCCCCC(=O)O
# SMILES for H2CO3: C(=O)(O)O
# SMILES for D-Galactopyranose: C(C1C(C(C(C(O1)O)O)O)O)O
# SMILES for D-Mannopyranose: C(C1C(C(C(C(O1)O)O)O)O)O
# SMILES for D-Glucopyranose: C(C1C(C(C(C(O1)O)O)O)O)O
# SMILES for Wood sugar: C1C(C(C(C(O1)O)O)O)O
# SMILES for Molybdate: [O-][Mo](=O)(=O)[O-]
# SMILES for Vitamin B12s: CC1=CC2=C(C=C1C)N(C=N2)C3C(C(C(O3)CO)OP(=O)(O)OC(C)CNC(=O)CCC4(C(C5C6(C(C(C(=N6)C(=C7C(C(C(=N7)C=C8C(C(C(=N8)C(=C4[N-]5)C)CCC(=O)N)(C)C)CCC(=O)N)(C)CC(=O)N)C)CCC(=O)N)(C)CC(=O)N)C)CC(=O)N)C)O.[Co]
# SMILES for Pyridoxol: CC1=NC=C(C(=C1O)CO)CO
# SMILES for Antiberiberi factor: CC1=C(SC=[N+]1CC2=CN=C(N=C2N)C)CCO
# SMILES for 3-Pyridinecarboxylic acid: C1=CC(=CN=C1)C(=O)O
# SMILES for p-Aminobenzoate: C1=CC(=CC=C1C(=O)[O-])N
# SMILES for Coenzyme R: C1C2C(C(S1)CCCCC(=O)O)NC(=O)N2
# SMILES for Folic acid: C1=CC(=CC=C1C(=O)NC(CCC(=O)O)C(=O)O)NCC2=CN=C3C(=N2)C(=O)NC(=N3)N
# SMILES for Iron(2+): [Fe+2]
# SMILES for Orthophosphoric acid: OP(=O)(O)O
# SMILES for D-Glycerol 1-phosphate: C(C(COP(=O)(O)O)O)O
# SMILES for D-arabino-Hexulose: C(C1C(C(C(O1)(CO)O)O)O)O
# SMILES for Hydron: [H+]
# SMILES for 1-alpha-D-Glucopyranosyl-2-beta-D-fructofuranoside: C(C1C(C(C(C(O1)OC2(C(C(C(O2)CO)O)O)CO)O)O)O)O
# SMILES for 1,2,3-Propanetriol: C(C(CO)O)O
# SMILES for 1-beta-D-Glucopyranosyl-4-D-glucopyranose: C(C1C(C(C(C(O1)OC2C(OC(C(C2O)O)O)CO)O)O)O)O
# SMILES for Butyric acid: CCCC(=O)O
# SMILES for Cetylic acid: CCCCCCCCCCCCCCCC(=O)O
# SMILES for L-Arabinopyranose: C1C(C(C(C(O1)O)O)O)O

# %%
print(name_smiles)
# Out:
# {'H2O;': None, 'Water': 'O', 'ATP;': None, "Adenosine 5'-triphosphate": 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)OP(=O)(O)O)O)O)N', 'NAD+;': None, 'NAD;': None, 'Nicotinamide adenine dinucleotide;': None, 'DPN;': None, 'Diphosphopyridine nucleotide;': None, 'Nadide;': None, 'beta-NAD+': 'C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)([O-])OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O)C(=O)N', 'NADH;': None, 'DPNH;': None, 'Reduced nicotinamide adenine dinucleotide': 'C1C=CN(C=C1C(=O)N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)O)O)O)O', 'NADPH;': None, 'TPNH;': None, 'Reduced nicotinamide adenine dinucleotide phosphate': 'C1C=CN(C=C1C(=O)N)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)OP(=O)(O)O)O)O)O', 'NADP+;': None, 'NADP;': None, 'Nicotinamide adenine dinucleotide phosphate;': None, 'beta-Nicotinamide adenine dinucleotide phosphate;': None, 'TPN;': None, 'Triphosphopyridine nucleotide;': None, 'beta-NADP+': 'C1=CC(=C[N+](=C1)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OCC3C(C(C(O3)N4C=NC5=C(N=CN=C54)N)OP(=O)(O)O)O)O)O)C(=O)N', 'Oxygen;': None, 'O2': 'O=O', 'ADP;': None, "Adenosine 5'-diphosphate": 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O)N', 'Orthophosphate;': None, 'Phosphate;': None, 'Phosphoric acid;': None, 'Orthophosphoric acid': 'OP(=O)(O)O', 'CoA;': None, 'Coenzyme A;': None, 'CoA-SH': 'CC(C)(COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)C(C(=O)NCCC(=O)NCCS)O', 'CO2;': None, 'Carbon dioxide': 'C(=O)=O', 'Diphosphate;': None, 'Diphosphoric acid;': None, 'Pyrophosphate;': None, 'Pyrophosphoric acid;': None, 'PPi': None, 'Ammonia;': None, 'NH3': 'N', 'UDP;': None, "Uridine 5'-diphosphate": 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)O)O)O', 'FAD;': None, 'Flavin adenine dinucleotide': 'CC1=CC2=C(C=C1C)N(C3=NC(=O)NC(=O)C3=N2)CC(C(C(COP(=O)(O)OP(=O)(O)OCC4C(C(C(O4)N5C=NC6=C(N=CN=C65)N)O)O)O)O)O', 'Pyridoxal phosphate;': None, "Pyridoxal 5'-phosphate;": None, 'Pyridoxal 5-phosphate;': None, 'PLP': 'CC1=NC=C(C(=C1O)C=O)COP(=O)(O)O', 'S-Adenosyl-L-methionine;': None, 'S-Adenosylmethionine;': None, 'AdoMet;': None, 'SAM': 'C[S+](CCC(C(=O)[O-])N)CC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)O', 'AMP;': None, "Adenosine 5'-monophosphate;": None, 'Adenylic acid;': None, 'Adenylate;': None, "5'-AMP;": None, "5'-Adenylic acid;": None, "5'-Adenosine monophosphate;": None, "Adenosine 5'-phosphate": 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)COP(=O)(O)O)O)O)N', 'S-Adenosyl-L-homocysteine;': None, 'S-Adenosylhomocysteine': 'C1=NC(=C2C(=N1)N(C=N2)C3C(C(C(O3)CSCCC(C(=O)O)N)O)O)N', 'Pyruvate;': None, 'Pyruvic acid;': None, '2-Oxopropanoate;': None, '2-Oxopropanoic acid;': None, 'Pyroracemic acid': 'CC(=O)C(=O)O', 'Acetyl-CoA;': None, 'Acetyl coenzyme A': 'CC(=O)SCCNC(=O)CCNC(=O)C(C(C)(C)COP(=O)(O)OP(=O)(O)OCC1C(C(C(O1)N2C=NC3=C(N=CN=C32)N)O)OP(=O)(O)O)O', 'L-Glutamate;': None, 'L-Glutamic acid;': None, 'L-Glutaminic acid;': None, 'Glutamate': 'C(CC(=O)O)C(C(=O)O)N', '2-Oxoglutarate;': None, 'Oxoglutaric acid;': None, '2-Ketoglutaric acid;': None, 'alpha-Ketoglutaric acid': 'C(CC(=O)O)C(=O)C(=O)O', 'Hydrogen peroxide;': None, 'H2O2;': None, 'Oxydol': 'OO', 'UDP-glucose;': None, 'UDPglucose;': None, 'UDP-D-glucose;': None, 'Uridine diphosphate glucose;': None, 'UDP-alpha-D-glucose': 'C1=CN(C(=O)NC1=O)C2C(C(C(O2)COP(=O)(O)OP(=O)(O)OC3C(C(C(C(O3)CO)O)O)O)O)O', 'D-Glucose;': None, 'Grape sugar;': None, 'Dextrose;': None, 'Glucose;': None, 'D-Glucopyranose': 'C(C1C(C(C(C(O1)O)O)O)O)O', 'Heme;': None, 'Haem;': None, 'Protoheme;': None, 'Heme B;': None, 'Protoheme IX': 'CC1=C(C2=CC3=C(C(=C([N-]3)C=C4C(=C(C(=N4)C=C5C(=C(C(=N5)C=C1[N-]2)C)C=C)C)C=C)C)CCC(=O)O)CCC(=O)O.[Fe+2]', 'Acetate;': None, 'Acetic acid;': None, 'Ethanoic acid': 'CC(=O)O', 'GDP;': None, "Guanosine 5'-diphosphate;": None, 'Guanosine diphosphate': 'C1=NC2=C(N1C3C(C(C(O3)COP(=O)(O)OP(=O)(O)O)O)O)N=C(NC2=O)N', 'Oxaloacetate;': None, 'Oxalacetic acid;': None, 'Oxaloacetic acid;': None, '2-Oxobutanedioic acid;': None, '2-Oxosucci ...

# %%
# come back to this later maybe?
from bioservices import *

kegg_con = KEGG()
chebi_con = ChEBI()

metabs_with_smiles = []
smiles_list = []
missing_metabs = []

for metabolite in curated_metabolites: 
    kegg_entry = kegg_con.parse(kegg_con.get(metabolite))
    try:
        chebi_entry = chebi_con.getCompleteEntity('CHEBI:' + kegg_entry['DBLINKS']['ChEBI'])
    except:
        missing_metabs.append(metabolite)
    else:
        try:
            smiles_list.append(chebi_entry.smiles)
        except: 
            missing_metabs.append(metabolite)
        else:
            metabs_with_smiles.append(metabolite)
            

print(len(metabolites))
print(len(metabs_with_smiles))
print(len(missing_metabs))

# %%
print(len(metabolites))
print(len(metabs_with_smiles))
print(len(missing_metabs))
print(missing_metabs[0:5])

# %%
metnames = []
missing_metabs2 = []
for metabolite in missing_metabs:
    try:
        kegg_con = KEGG()
        metname = kegg_con.parse(kegg_con.get(metabolite))['NAME']
        metnames.append(metname)
    except: missing_metabs2.append(metabolite)
print(len(metnames))
print(len(missing_metabs2))

# %%
print(metnames)  # Names of metabs missing SMILES right now

# %%
chebi_entry = chebi_con.getCompleteEntity('CHEBI:' + kegg_entry['DBLINKS']['ChEBI'])

# %%
import csv
with open('metabs_with_smiles.csv', 'w') as outfile:
    wr = csv.writer(outfile)
    wr.writerow(metabs_with_smiles)
    outfile.close()
    
with open('missing_metabs.csv', 'w') as outfile:
    wr = csv.writer(outfile)
    wr.writerow(missing_metabs)
    outfile.close()

with open ('smiles.csv', 'w') as outfile:
    wr = csv.writer(outfile)
    wr.writerow(smiles_list)
    outfile.close()

# %%
# Adds compartment names to the model.
model.compartments = {'c': 'Cytoplasm'}
model.compartments = {'e': 'Extracellular'}
model.compartments

# %% [markdown]
# # Save model

# %%
# Output model for use with Gecko in Matlab
cobra.io.save_matlab_model(model, '../../Models/iGEL604_update.mat')

# %% [markdown]
# # To do later

# %%
# Finds 125 reactions still missing names in the model. Fix later given time.
counter = 0
for reaction in model.reactions:
    if reaction.name == '':
        print("%s  %s %s" %(reaction.id, reaction.name, reaction.bounds))
        counter += 1
print('Number of reactions missing name: %i' %(counter))

# %% [markdown]
# # Playing with KEGG API (REST)
# Would love to be able to fill in missing reaction names using the rXYZ... KEGG identifiers in the model.
#
# Tutorial: https://widdowquinn.github.io/2018-03-06-ibioic/02-sequence_databases/09-KEGG_programming.html#imports

# %%
from Bio.KEGG import REST
import io

# %%
def to_df(result):
    return pd.read_table(io.StringIO(result), header=None)

# %%
test = REST.kegg_info("reaction").read()  # Gets database info
print(test)

# %%
test = REST.kegg_list("reaction").read()
print(test)

# %%
# Get all G. LC300 pathways in dataframe
test = REST.kegg_list("pathway", "gel").read()
lc300_pathways = to_df(test)
lc300_pathways

# %%
lc300_info = REST.kegg_info("gel").read()
print(lc300_info)

# %%
REST.kegg_get("gel:IB49_00015").read()

# %%
help(REST.kegg_get)
